# %% [markdown]
# # Scraping Stackoverflow Questions

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
res = requests.get("https://stackoverflow.com/questions")

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %%
soup.head()
# Out:
# [<title>Newest Questions - Stack Overflow</title>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>,
#  <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>,
#  <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>,
#  <meta content="website" property="og:type">
#  <meta content="https://stackoverflow.com/questions" property="og:url"/>
#  <meta content="Stack Overflow" property="og:site_name"/>
#  <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="stackoverflow.com" name="twitter:domain"/>
#  <meta content="Newest Questions" itemprop="name" name="twitter:title" property="og:title"/>
#  <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
#  <script src="https://cdn.sstatic.net/Js/stub.en.js?v=ae62f735acf1"></script>
#  <link href="https://cdn.sstatic.net/Shared/stacks.css?v=13d89c0c9941" rel="stylesheet" type="text/css"/>
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=2a54031b08a6" rel="stylesheet" type="text/css"/>
#  <script>
#          StackExchange.init({"locale":"en","serverTime":1600307552,"routeName":"Questions/List","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"childUrl":"https://meta.stackoverflow.com","styleCodeWithHighlightjs":false,"negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"4c68b862989664dbad0abdbd8bc2e03531d90cb93092ac7983b741f8aeca92da","tid":"8de12f12-fcc7-e184-7ba3-4cdb87a9dbbe","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/svg-icons","svgIconHash":"e06df390d347"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"slack":{"sidebarAdDismissCookie":"slack-sidebar-ad","sidebarAdDismissCookieExpirationDays":60.0},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#          StackExchange.using.setCacheBreakers({"js/adops.en.js":"22a9bd59b1e9","js/ask.en.js":"83cc8cb596d5","js/begin-edit-event.en.js":"cb9965ad8784","js/events.en.js":"76e1cbcf42ae","js/explore-qlist.en.js":"4556f86d8730","js/full-anon.en.js":"fe8573dfb8a1","js/full.en.js":"38d7efd71517","js/help.en.js":"6a9178c1ea2a","js/highlightjs-loader.en.js":"76b9cf2cd902","js/inline-tag-editing.en.js":"88510a5b8778","js/keyboard-shortcuts.en.js":"c9ee7e3f5382","js/markdown-it-loader.en.js":"d0c0c5aa47f6","js/mobile.en.js":"7c56da39f21a","js/moderator.en.js":"b62ce0f34b23","js/postCollections-transpiled.en.js":"f9147073caf6","js/post-validation.en.js":"3591b67b253a","js/prettify-full.en.js":"3ff8effcec81","js/question-editor.en.js":"","js/review.en.js":"aeb8473fe536","js/revisions.en.js":"21da4c377f56","js/stacks-editor.en.js":"178ccb2d4e45","js/tageditor.en.js":"0ffdcf3fc9c4","js/tageditornew.en.js":"5b8b827ee7c9","js/tagsuggestions.en.js":"9b2c5d9791d2","js/wmd.en.js":"083f53e95f03","js/snippet-javascript-codemirror.en.js":"9e7d06feb678"});
#          StackExchange.using("gps", function() {
#               StackExchange.gps.init(true);
#          });
#      </script>
#  <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>
#  </meta>,
#  <meta content="https://stackoverflow.com/questions" property="og:url"/>,
#  <meta content="Stack Overflow" property="og:site_name"/>,
#  <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>,
#  <meta content="summary" name="twitter:card"/>,
#  <meta content="stackoverflow.com" name="twitter:domain"/>,
#  <meta content="Newest Questions" itemprop="name" name="twitter:title" property="og:title"/>,
#  <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>,
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>,
#  <script src="https://cdn.sstatic.net/Js/stub.en.js?v=ae62f735acf1"></script>,
#  <link href="https://cdn.sstatic.net/Shared/stacks.css?v=13d89c0c9941" rel="stylesheet" type="text/css"/>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=2a54031b08a6" rel="stylesheet" type="text/css"/>,
#  <script>
#          StackExchange.init({"locale":"en","serverTime":1600307552,"routeName":"Questions/List","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"childUrl":"https://meta.stackoverflow.com","styleCodeWithHighlightjs":false,"negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"4c68b862989664dbad0abdbd8bc2e03531d90cb93092ac7983b741f8aeca92da","tid":"8de12f12-fcc7-e184-7ba3-4cdb87a9dbbe","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/svg-icons","svgIconHash":"e06df390d347"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"slack":{"sidebarAdDismissCookie":"slack-sidebar-ad","sidebarAdDismissCookieExpirationDays":60.0},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#          StackExchange.using.setCacheBreakers({"js/adops.en.js":"22a9bd59b1e9","js/ask.en.js":"83cc8cb596d5","js/begin-edit-event.en.js":"cb9965ad8784","js/events.en.js":"76e1cbcf42ae","js/explore-qlist.en.js":"4556f86d8730","js/full-anon.en.js":"fe8573dfb8a1","js/full.en.js":"38d7efd71517","js/help.en.js":"6a9178c1ea2a","js/highlightjs-loader.en.js":"76b9cf2cd902","js/inline-tag-editing.en.js":"88510a5b8778","js/keyboard-shortcuts.en.js":"c9ee7e3f5382","js/markdown-it-loader.en.js":"d0c0c5aa47f6","js/mobile.en.js":"7c56da39f21a","js/moderator.en.js":"b62ce0f34b23","js/postCollections-transpiled.en.js":"f9147073caf6","js/post-validation.en.js":"3591b67b253a","js/prettify-full.en.js":"3ff8effcec81","js/question-editor.en.js":"","js/review.en.js":"aeb8473fe536","js/revisions.en.js":"21da4c377f56","js/stacks-editor.en.js":"178ccb2d4e45","js/tageditor.en.js":"0ffdcf3fc9c4","js/tageditornew.en.js":"5b8b827ee7c9","js/tagsuggestions.en.js":"9b2c5d9791d2","js/wmd.en.js":"083f53e95f03","js/snippet-javascript-codemirror.en.js":"9e7d06feb678"});
#          StackExchange.using("gps", function() {
#               StackExchange.gps.init(true);
#          });
#      </script>,
#  <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>,
#  <style>body,.top-bar{margin-top:1.9em}</style>]

# %%
questions = soup.select(".question-summary")

# %%
questions
# Out:
# [<div class="question-summary" id="question-summary-63930157">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930157/ragged-tensor-to-numpy-or-list">ragged tensor to numpy or list?</a></h3>
#  <div class="excerpt">
#              Let say I have a lagged tensor
#  lst = &lt;tf.RaggedTensor [[13, 15]]&gt;
#
#  then if I want to change this to the numpy array to list?
#  tensorflow 2.2.0
#          </div>
#  <div class="tags t-python t-list t-tensorflow2û0">
#  <a class="post-tag" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag" href="/questions/tagged/list" rel="tag" title="show questions tagged 'list'">list</a> <a class="post-tag" href="/questions/tagged/tensorflow2.0" rel="tag" title="show questions tagged 'tensorflow2.0'">tensorflow2.0</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:51:42Z">49 secs ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14001694/user6507246"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://i.stack.imgur.com/9OjfQ.png?s=32&amp;g=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14001694/user6507246">user6507246</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">21</span><span aria-hidden="true" title="1 bronze badge"><span class="badge3"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 bronze badge</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930155">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="2 views">
#      2 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930155/q-mapbox-heatmap-hide-outside-boundaries">Q: MapBox Heatmap hide outside boundaries</a></h3>
#  <div class="excerpt">
#              I'm creating a heatmap of the United States and the designers want to "stop" the color from bleeding outside the US borders. So under Texas, the colors would reach the edge of the state and ...
#          </div>
#  <div class="tags t-heatmap t-mapbox-gl-js">
#  <a class="post-tag" href="/questions/tagged/heatmap" rel="tag" title="show questions tagged 'heatmap'">heatmap</a> <a class="post-tag" href="/questions/tagged/mapbox-gl-js" rel="tag" title="show questions tagged 'mapbox-gl-js'">mapbox-gl-js</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:51:23Z">1 min ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/8880869/mediocre-bro"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/b053b157c8a1728b5fd19c38324a2ee0?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/8880869/mediocre-bro">mediocre_bro</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">55</span><span aria-hidden="true" title="6 bronze badges"><span class="badge3"></span><span class="badgecount">6</span></span><span class="v-visible-sr">6 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930154">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="4 views">
#      4 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930154/python-best-practice-for-looping-backwards-in-for-loop-without-reversing-the-arr">Python Best Practice for Looping Backwards in For Loop without reversing the array</a></h3>
#  <div class="excerpt">
#              In doing problems on Leetcode etc it's often required to iterate from the end of the array to the front and I'm used to more traditional programming languages where the for loop is less awkward  i.e. ...
#          </div>
#  <div class="tags t-python">
#  <a class="post-tag" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:51:21Z">1 min ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14277496/alee18"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/85468f6d893019ca29024bfc58aad1fa?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14277496/alee18">alee18</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">3</span><span aria-hidden="true" title="1 bronze badge"><span class="badge3"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 bronze badge</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930153">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930153/skip-binding-id-but-return-it-as-a-response">Skip binding ID but return it as a response</a></h3>
#  <div class="excerpt">
#              I have a Person struct as follows:
#  type Person struct {
#    ID primitive.ObjectID `bson:"_id,omitempty" json:"id"`
#    HomeAddress Address `bson:"home_address" json:"...
#          </div>
#  <div class="tags t-mongodb t-rest t-go t-go-gin">
#  <a class="post-tag" href="/questions/tagged/mongodb" rel="tag" title="show questions tagged 'mongodb'">mongodb</a> <a class="post-tag" href="/questions/tagged/rest" rel="tag" title="show questions tagged 'rest'">rest</a> <a class="post-tag" href="/questions/tagged/go" rel="tag" title="show questions tagged 'go'">go</a> <a class="post-tag" href="/questions/tagged/go-gin" rel="tag" title="show questions tagged 'go-gin'">go-gin</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:51:21Z">1 min ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/11263733/nanakondor"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/e8918bbb3bc69e11f5d0960ce8eb65fc?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/11263733/nanakondor">nanakondor</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">173</span><span aria-hidden="true" title="8 bronze badges"><span class="badge3"></span><span class="badgecount">8</span></span><span class="v-visible-sr">8 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930152">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930152/using-lambda-to-pull-image-from-docker-hub-and-push-to-ecr">Using lambda to pull image from Docker hub and push to ECR</a></h3>
#  <div class="excerpt">
#              Our code deployment pipeline uses ECR to maintain images and there are some public images that we use from Docker hub.
#  We would manually pull the images and then push to ECR. I would like to automate ...
#          </div>
#  <div class="tags t-amazon-web-services t-docker t-aws-lambda t-amazon-ecr">
#  <a class="post-tag" href="/questions/tagged/amazon-web-services" rel="tag" title="show questions tagged 'amazon-web-services'">amazon-web-services</a> <a class="post-tag" href="/questions/tagged/docker" rel="tag" title="show questions tagged 'docker'">docker</a> <a class="post-tag" href="/questions/tagged/aws-lambda" rel="tag" title="show questions tagged 'aws-lambda'">aws-lambda</a> <a class="post-tag" href="/questions/tagged/amazon-ecr" rel="tag" title="show questions tagged 'amazon-ecr'">amazon-ecr</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:51:19Z">1 min ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/455048/madu"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/e5222d4a40e94bb2095e5e429b65ad3f?s=32&amp;d=identicon&amp;r=PG" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/455048/madu">madu</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">4,416</span><span aria-hidden="true" title="11 gold badges"><span class="badge1"></span><span class="badgecount">11</span></span><span class="v-visible-sr">11 gold badges</span><span aria-hidden="true" title="43 silver badges"><span class="badge2"></span><span class="badgecount">43</span></span><span class="v-visible-sr">43 silver badges</span><span aria-hidden="true" title="70 bronze badges"><span class="badge3"></span><span class="badgecount">70</span></span><span class="v-visible-sr">70 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930149">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930149/andron-cnc-data-file">Andron CNC data file</a></h3>
#  <div class="excerpt">
#              My goal is to read the status of a CNC machine that uses an Andron controller. There is a data file located on the machine that I want to use to read the status with. However, I have ran into a ...
#          </div>
#  <div class="tags t-cçç t-cnc">
#  <a class="post-tag" href="/questions/tagged/c%2b%2b" rel="tag" title="show questions tagged 'c++'">c++</a> <a class="post-tag" href="/questions/tagged/cnc" rel="tag" title="show questions tagged 'cnc'">cnc</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:51:14Z">1 min ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14249930/krait"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/c3a4611b5125afb4a9f428d998ffbb90?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14249930/krait">Krait</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930141">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930141/how-to-start-embedded-tomcat-to-test-spring-controller-not-to-use-springbootte">How to start embedded tomcat to test spring controller, not to use @SpringBootTest?</a></h3>
#  <div class="excerpt">
#              Because my project is too old, using Spring 4.3 not spring boot, so I cannot use @SpringBootTest to run embedded server.
#  And I don't wanna use MockMvc to test controllers/gateway, since it will ignore ...
#          </div>
#  <div class="tags t-spring">
#  <a class="post-tag" href="/questions/tagged/spring" rel="tag" title="show questions tagged 'spring'">spring</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info user-hover">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:50:33Z">1 min ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/4883754/kyakya"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://i.stack.imgur.com/q2xcu.png?s=32&amp;g=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/4883754/kyakya">kyakya</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">399</span><span aria-hidden="true" title="3 silver badges"><span class="badge2"></span><span class="badgecount">3</span></span><span class="v-visible-sr">3 silver badges</span><span aria-hidden="true" title="6 bronze badges"><span class="badge3"></span><span class="badgecount">6</span></span><span class="v-visible-sr">6 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930140">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="4 views">
#      4 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930140/how-do-i-create-a-sequence-of-number-character-with-seq-and-rep">How do i create a sequence of number/ character with seq() and rep()</a></h3>
#  <div class="excerpt">
#              How do I create the following sequence in R with seq(), or rep() and some other operators/functions appropriately, but not c() and not []:
#  1 20 300 4000 50000
#  “x1” “y2” “y3” “z4” “z5” “z6”
#  2 3 4 5 1 3 ...
#          </div>
#  <div class="tags t-r t-seq t-rep">
#  <a class="post-tag" href="/questions/tagged/r" rel="tag" title="show questions tagged 'r'">r</a> <a class="post-tag" href="/questions/tagged/seq" rel="tag" title="show questions tagged 'seq'">seq</a> <a class="post-tag" href="/questions/tagged/rep" rel="tag" title="show questions tagged 'rep'">rep</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:50:14Z">2 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14291084/kenneth-pomeyie"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh3.googleusercontent.com/a-/AOh14Gg1dQr-53eqlyvIn4_4srtMeY-G-nWIPHMFP5HBXw=k-s32" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14291084/kenneth-pomeyie">Kenneth Pomeyie</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span><span aria-hidden="true" title="1 bronze badge"><span class="badge3"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 bronze badge</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930139">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="5 views">
#      5 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930139/join-path-additionalchildpath-parameter-deprecated-or-am-i-misusing">Join-Path AdditionalChildPath parameter deprecated or am I misusing?</a></h3>
#  <div class="excerpt">
#              I am trying to use Join-Path to join a path with 4 subpaths:
#  path1 = "Users"
#  path2 = "Bob"
#  path3 = "Documents"
#  path4 = "project"
#
#  So that when the paths are ...
#          </div>
#  <div class="tags t-powershell t-cmdlets">
#  <a class="post-tag" href="/questions/tagged/powershell" rel="tag" title="show questions tagged 'powershell'">powershell</a> <a class="post-tag" href="/questions/tagged/cmdlets" rel="tag" title="show questions tagged 'cmdlets'">cmdlets</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:50:09Z">2 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/8346493/anna"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/e40826a009d134cc90abbb2e3e36b277?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/8346493/anna">Anna</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">199</span><span aria-hidden="true" title="11 bronze badges"><span class="badge3"></span><span class="badgecount">11</span></span><span class="v-visible-sr">11 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930138">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930138/calculate-standard-deviation-using-r">Calculate standard deviation using R</a></h3>
#  <div class="excerpt">
#              Using the R script solve the following:
#  An expert on process control states that he is 95% confident that the new production process will save between $26 and $38 per unit with savings values around $...
#          </div>
#  <div class="tags t-r t-standard-deviation">
#  <a class="post-tag" href="/questions/tagged/r" rel="tag" title="show questions tagged 'r'">r</a> <a class="post-tag" href="/questions/tagged/standard-deviation" rel="tag" title="show questions tagged 'standard-deviation'">standard-deviation</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:50:08Z">2 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/2683290/nad"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/a1f1ca640ad6cba282ec0a9b4d6cdec2?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/2683290/nad">NAD</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">23</span><span aria-hidden="true" title="1 silver badge"><span class="badge2"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 silver badge</span><span aria-hidden="true" title="5 bronze badges"><span class="badge3"></span><span class="badgecount">5</span></span><span class="v-visible-sr">5 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930134">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="5 views">
#      5 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930134/sql-column-count-does-not-match">SQL: Column count does not match</a></h3>
#  <div class="excerpt">
#              I'm trying to insert values from two tables into a new table, but I keep getting the 'column count does not match' when it does. This is what I have so far:
#  create table contribution (
#    contb_id      ...
#          </div>
#  <div class="tags t-sql">
#  <a class="post-tag" href="/questions/tagged/sql" rel="tag" title="show questions tagged 'sql'">sql</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:49:41Z">2 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14291031/ethan"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/2c759357b25a9b22ff2643682d0f625a?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14291031/ethan">Ethan</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930133">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="4 views">
#      4 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930133/css-loading-slow-and-causing-temporary-weird-formatting-on-laravel-app-with-blad">CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue</a></h3>
#  <div class="excerpt">
#              I have a Laravel app that uses a tiny bit of Vue code in the blade templates. There's a problem navigating from view to view, almost every time there's a brief delay before the CSS is loaded where the ...
#          </div>
#  <div class="tags t-laravel t-vueûjs t-laravel-blade">
#  <a class="post-tag" href="/questions/tagged/laravel" rel="tag" title="show questions tagged 'laravel'">laravel</a> <a class="post-tag" href="/questions/tagged/vue.js" rel="tag" title="show questions tagged 'vue.js'">vue.js</a> <a class="post-tag" href="/questions/tagged/laravel-blade" rel="tag" title="show questions tagged 'laravel-blade'">laravel-blade</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:49:39Z">2 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/1801713/matt"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/6db1fdaaf5efff6bb149594564f07787?s=32&amp;d=identicon&amp;r=PG" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/1801713/matt">Matt</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1,186</span><span aria-hidden="true" title="2 gold badges"><span class="badge1"></span><span class="badgecount">2</span></span><span class="v-visible-sr">2 gold badges</span><span aria-hidden="true" title="14 silver badges"><span class="badge2"></span><span class="badgecount">14</span></span><span class="v-visible-sr">14 silver badges</span><span aria-hidden="true" title="20 bronze badges"><span class="badge3"></span><span class="badgecount">20</span></span><span class="v-visible-sr">20 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930130">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="7 views">
#      7 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930130/python-a-zero-length-asyncio-queue">python: a zero-length asyncio queue</a></h3>
#  <div class="excerpt">
#              asyncio.Queue supports setting a maxsize, causing put() to block until there is room in the queue. But the smallest possible maxsize is 1. This extra buffer can cause delays in realtime programming. ...
#          </div>
#  <div class="tags t-python t-asynchronous t-real-time">
#  <a class="post-tag" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag" href="/questions/tagged/asynchronous" rel="tag" title="show questions tagged 'asynchronous'">asynchronous</a> <a class="post-tag" href="/questions/tagged/real-time" rel="tag" title="show questions tagged 'real-time'">real-time</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:49:16Z">3 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/1840698/enigmaticphysicist"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/a5e431c98ba2338726488519b9480784?s=32&amp;d=identicon&amp;r=PG" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/1840698/enigmaticphysicist">enigmaticPhysicist</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">998</span><span aria-hidden="true" title="10 silver badges"><span class="badge2"></span><span class="badgecount">10</span></span><span class="v-visible-sr">10 silver badges</span><span aria-hidden="true" title="14 bronze badges"><span class="badge3"></span><span class="badgecount">14</span></span><span class="v-visible-sr">14 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930129">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="3 views">
#      3 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930129/how-to-converet-readblestrem-to-json">How to converet Readblestrem to JSON</a></h3>
#  <div class="excerpt">
#              I'm preforming fetch, with method: POST to sign in.
#  fetch(
#          "URL/account/login?email=something@gmail.com&amp;password=test0123",
#          {
#            method: "POST",
#           ...
#          </div>
#  <div class="tags t-json t-api t-vueûjs">
#  <a class="post-tag" href="/questions/tagged/json" rel="tag" title="show questions tagged 'json'">json</a> <a class="post-tag" href="/questions/tagged/api" rel="tag" title="show questions tagged 'api'">api</a> <a class="post-tag" href="/questions/tagged/vue.js" rel="tag" title="show questions tagged 'vue.js'">vue.js</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:49:11Z">3 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/4602966/user4602966"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/339563cec77da85e248d212abdfa9521?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/4602966/user4602966">user4602966</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">67</span><span aria-hidden="true" title="1 silver badge"><span class="badge2"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 silver badge</span><span aria-hidden="true" title="6 bronze badges"><span class="badge3"></span><span class="badgecount">6</span></span><span class="v-visible-sr">6 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930128">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="4 views">
#      4 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930128/nesting-components-with-createelement-in-react-yields-error">nesting components with createElement in React yields error</a></h3>
#  <div class="excerpt">
#              I'm trying to create a helper function that nest a passed element/component as a children of itself of several depths.
#  So something like this
#  const Chain = nested(4, () =&gt; &lt;div /&gt;)
#  return (
#    ...
#          </div>
#  <div class="tags t-reactjs t-typescript t-error-handling t-components t-jsx">
#  <a class="post-tag" href="/questions/tagged/reactjs" rel="tag" title="show questions tagged 'reactjs'">reactjs</a> <a class="post-tag" href="/questions/tagged/typescript" rel="tag" title="show questions tagged 'typescript'">typescript</a> <a class="post-tag" href="/questions/tagged/error-handling" rel="tag" title="show questions tagged 'error-handling'">error-handling</a> <a class="post-tag" href="/questions/tagged/components" rel="tag" title="show questions tagged 'components'">components</a> <a class="post-tag" href="/questions/tagged/jsx" rel="tag" title="show questions tagged 'jsx'">jsx</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info user-hover">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:48:59Z">3 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/11389585/terry"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://i.stack.imgur.com/mXSX2.gif?s=32&amp;g=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/11389585/terry">Terry</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">67</span><span aria-hidden="true" title="1 silver badge"><span class="badge2"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 silver badge</span><span aria-hidden="true" title="7 bronze badges"><span class="badge3"></span><span class="badgecount">7</span></span><span class="v-visible-sr">7 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930125">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="9 views">
#      9 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930125/pass-a-second-value-from-authentication-with-swashbuckle-swagger">Pass a second value from authentication with Swashbuckle (Swagger)</a></h3>
#  <div class="excerpt">
#              I have setup Swashbuckle to do authentication (and it is working):
#  ConfigureServices
#  services.AddSwaggerGen(c =&gt;
#  {
#      c.SwaggerDoc("v1", new OpenApiInfo { Title = "WebAPI ...
#          </div>
#  <div class="tags t-cñ t-aspûnet-core t-aspûnet-core-3û1 t-swashbuckle t-swashbuckleûaspnetcore">
#  <a class="post-tag" href="/questions/tagged/c%23" rel="tag" title="show questions tagged 'c#'">c#</a> <a class="post-tag" href="/questions/tagged/asp.net-core" rel="tag" title="show questions tagged 'asp.net-core'">asp.net-core</a> <a class="post-tag" href="/questions/tagged/asp.net-core-3.1" rel="tag" title="show questions tagged 'asp.net-core-3.1'">asp.net-core-3.1</a> <a class="post-tag" href="/questions/tagged/swashbuckle" rel="tag" title="show questions tagged 'swashbuckle'">swashbuckle</a> <a class="post-tag" href="/questions/tagged/swashbuckle.aspnetcore" rel="tag" title="show questions tagged 'swashbuckle.aspnetcore'">swashbuckle.aspnetcore</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info user-hover">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:48:14Z">4 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/16241/vaccano"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/de3fa0861da7fd9ae3abc120ff6d957f?s=32&amp;d=identicon&amp;r=PG" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/16241/vaccano">Vaccano</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score 67,682">67.7k</span><span aria-hidden="true" title="122 gold badges"><span class="badge1"></span><span class="badgecount">122</span></span><span class="v-visible-sr">122 gold badges</span><span aria-hidden="true" title="379 silver badges"><span class="badge2"></span><span class="badgecount">379</span></span><span class="v-visible-sr">379 silver badges</span><span aria-hidden="true" title="712 bronze badges"><span class="badge3"></span><span class="badgecount">712</span></span><span class="v-visible-sr">712 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930124">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="6 views">
#      6 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930124/is-there-a-way-to-have-a-timer-bean-schedule-method-execute-on-single-glassfish">Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?</a></h3>
#  <div class="excerpt">
#              Our setup (non-negotiable):
#  Multiple Glassfish 5 instances on JDK 8 running the same Application behind an external loadbalancer i.e. not clustered - separate JVMs.
#  The requirement:
#  To have an EJB-...
#          </div>
#  <div class="tags t-glassfish t-java-ee-6 t-java-ee-7 t-java-ee-8 t-ejb-timer">
#  <a class="post-tag" href="/questions/tagged/glassfish" rel="tag" title="show questions tagged 'glassfish'">glassfish</a> <a class="post-tag" href="/questions/tagged/java-ee-6" rel="tag" title="show questions tagged 'java-ee-6'">java-ee-6</a> <a class="post-tag" href="/questions/tagged/java-ee-7" rel="tag" title="show questions tagged 'java-ee-7'">java-ee-7</a> <a class="post-tag" href="/questions/tagged/java-ee-8" rel="tag" title="show questions tagged 'java-ee-8'">java-ee-8</a> <a class="post-tag" href="/questions/tagged/ejb-timer" rel="tag" title="show questions tagged 'ejb-timer'">ejb-timer</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:48:05Z">4 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14291081/chris-odonnell"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh3.googleusercontent.com/a-/AOh14Gi---I3hVVUZY106sd6xb2txu8sE0Z1W2YuBNUz=k-s32" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14291081/chris-odonnell">Chris O'Donnell</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930121">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="6 views">
#      6 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930121/upload-jpg-with-flask-and-html">Upload jpg with flask and html</a></h3>
#  <div class="excerpt">
#              I'm a beginner and i'm making a blog with flask and html right now but it only can post title and content, but i want to post some picture init, so if anyone know whats the essayist way to post it (...
#          </div>
#  <div class="tags t-python t-html t-database t-flask t-upload">
#  <a class="post-tag" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag" href="/questions/tagged/html" rel="tag" title="show questions tagged 'html'">html</a> <a class="post-tag" href="/questions/tagged/database" rel="tag" title="show questions tagged 'database'">database</a> <a class="post-tag" href="/questions/tagged/flask" rel="tag" title="show questions tagged 'flask'">flask</a> <a class="post-tag" href="/questions/tagged/upload" rel="tag" title="show questions tagged 'upload'">upload</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:46:56Z">5 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/13825988/ericssonn"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh3.googleusercontent.com/a-/AOh14Ggwuv13nunN9d6Jy6URmT061yAu35_gTZzxNlQs=k-s32" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/13825988/ericssonn">Ericssonn</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930120">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>-2</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="7 views">
#      7 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930120/curl-request-through-ajax">cURL Request Through Ajax</a></h3>
#  <div class="excerpt">
#              To start, my jquery/javascript skills are fairly new, so I'm not really sure what I've doing.
#  I have a php file that is currently using cURL to send a request to an api and then returns the data.
#  I ...
#          </div>
#  <div class="tags t-javascript t-jquery t-ajax t-curl">
#  <a class="post-tag" href="/questions/tagged/javascript" rel="tag" title="show questions tagged 'javascript'">javascript</a> <a class="post-tag" href="/questions/tagged/jquery" rel="tag" title="show questions tagged 'jquery'">jquery</a> <a class="post-tag" href="/questions/tagged/ajax" rel="tag" title="show questions tagged 'ajax'">ajax</a> <a class="post-tag" href="/questions/tagged/curl" rel="tag" title="show questions tagged 'curl'">curl</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:46:43Z">5 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/10762273/chris-owens"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/d79c9fdd28eff233cae275415eeee75f?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/10762273/chris-owens">Chris Owens</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span><span aria-hidden="true" title="1 bronze badge"><span class="badge3"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 bronze badge</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930118">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status answered">
#  <strong>1</strong>answer
#              </div>
#  </div>
#  <div class="views" title="7 views">
#      7 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930118/why-am-i-getting-this-invalid-syntax-in-dictionary-using-python3">Why am I getting this invalid syntax in Dictionary using Python3?</a></h3>
#  <div class="excerpt">
#              Just started Python yesterday (after learning Javascript) and really liking the language. Just ran into this syntax error today and it does not make any sense to me. I have included a space before all ...
#          </div>
#  <div class="tags t-python-3ûx">
#  <a class="post-tag" href="/questions/tagged/python-3.x" rel="tag" title="show questions tagged 'python-3.x'">python-3.x</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:46:24Z">6 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14039739/bolmstead"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/3675e430dc495f82e813090eb200ec10?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14039739/bolmstead">Bolmstead</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">159</span><span aria-hidden="true" title="9 bronze badges"><span class="badge3"></span><span class="badgecount">9</span></span><span class="v-visible-sr">9 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930117">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="4 views">
#      4 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930117/react-router-link-component-setting-href-to-fully-qualified-url-instead-of-rela">React Router: Link component setting href to fully qualified url instead of relative</a></h3>
#  <div class="excerpt">
#              I am using react-router 5.2.0, react-router-dom 5.2.0, history 4.10.1.
#  I am creating a simple component that creates a Link. The component is passed a parameter called 'editURI' which is passed into ...
#          </div>
#  <div class="tags t-react-router t-react-router-component">
#  <a class="post-tag" href="/questions/tagged/react-router" rel="tag" title="show questions tagged 'react-router'">react-router</a> <a class="post-tag" href="/questions/tagged/react-router-component" rel="tag" title="show questions tagged 'react-router-component'">react-router-component</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info user-hover">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:46:20Z">6 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/5256690/alphadork"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://i.stack.imgur.com/18zqp.jpg?s=32&amp;g=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/5256690/alphadork">Alphadork</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">11</span><span aria-hidden="true" title="4 bronze badges"><span class="badge3"></span><span class="badgecount">4</span></span><span class="v-visible-sr">4 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930114">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="9 views">
#      9 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930114/i-want-to-do-user-finder-using-python-django">I want to do user finder using python django</a></h3>
#  <div class="excerpt">
#              class ForgotidAPI(generics.GenericAPIView):
#      serializer_class = ForgotidSerualizer
#
#      def post(self, request, *args, **kwargs):
#          Email = request.data.getlist('email')
#          ...
#          </div>
#  <div class="tags t-python t-django">
#  <a class="post-tag" href="/questions/tagged/python" rel="tag" title="show questions tagged 'python'">python</a> <a class="post-tag" href="/questions/tagged/django" rel="tag" title="show questions tagged 'django'">django</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:45:24Z">7 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14237957/handsomecode"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/d7e71ed2533afef9aca7c04269902897?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14237957/handsomecode">handsomecode</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">3</span><span aria-hidden="true" title="3 bronze badges"><span class="badge3"></span><span class="badgecount">3</span></span><span class="v-visible-sr">3 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930110">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="5 views">
#      5 views
#  </div>
#  </div>
#  <div class="summary">
# ...
#  <div class="excerpt">
#              I have a table of selections that has no relationship and only serves to be a selector for a filter:
#
#  I then have this feed a slicer on my page so that when the user selectes a value, the following ...
#          </div>
#  <div class="tags t-switch-statement t-powerbi t-linechart t-slicers">
#  <a class="post-tag" href="/questions/tagged/switch-statement" rel="tag" title="show questions tagged 'switch-statement'">switch-statement</a> <a class="post-tag" href="/questions/tagged/powerbi" rel="tag" title="show questions tagged 'powerbi'">powerbi</a> <a class="post-tag" href="/questions/tagged/linechart" rel="tag" title="show questions tagged 'linechart'">linechart</a> <a class="post-tag" href="/questions/tagged/slicers" rel="tag" title="show questions tagged 'slicers'">slicers</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:39:32Z">13 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/6377662/sqalex101"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/2fc6dba06fde7ce4aa3e061dc75674d0?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/6377662/sqalex101">SQALEX101</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">117</span><span aria-hidden="true" title="7 bronze badges"><span class="badge3"></span><span class="badgecount">7</span></span><span class="v-visible-sr">7 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930079">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="12 views">
#      12 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930079/merging-elements-of-array-in-scala">Merging elements of array in scala</a></h3>
#  <div class="excerpt">
#              I my scala code I have following array.
#  val myArray =  [Group(List(MyCondition(1,type1,List(Results(pass,fail))))), Group(List(MyCondition(2,type2,List(Results(pass,fail)))))]
#
#  I want to merge  this ...
#          </div>
#  <div class="tags t-scala">
#  <a class="post-tag" href="/questions/tagged/scala" rel="tag" title="show questions tagged 'scala'">scala</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:38:49Z">13 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14190485/zulia"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh5.googleusercontent.com/-vQne6iv8aj4/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmGMJ6144QlE2o3_-a9IYFlqkS_RA/photo.jpg?sz=32" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14190485/zulia">Zulia</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">13</span><span aria-hidden="true" title="2 bronze badges"><span class="badge3"></span><span class="badgecount">2</span></span><span class="v-visible-sr">2 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930078">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="5 views">
#      5 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930078/my-app-stores-my-token-but-i-cant-send-it-to-the-header">my app stores my token, but I can't send it to the header</a></h3>
#  <div class="excerpt">
#              I get the following error when I put validaToken () at login, the token is stored correctly in local storage.
#  I put in de server, but it does not work :
#   server.app.use( bodyParser.urlencoded({ ...
#          </div>
#  <div class="tags t-nodeûjs t-angular t-ionic-framework">
#  <a class="post-tag" href="/questions/tagged/node.js" rel="tag" title="show questions tagged 'node.js'">node.js</a> <a class="post-tag" href="/questions/tagged/angular" rel="tag" title="show questions tagged 'angular'">angular</a> <a class="post-tag" href="/questions/tagged/ionic-framework" rel="tag" title="show questions tagged 'ionic-framework'">ionic-framework</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:38:28Z">14 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14291005/dan"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/1b6da8b40f79cf3798d97e79403fe2ea?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14291005/dan">Dan</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span><span aria-hidden="true" title="1 bronze badge"><span class="badge3"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 bronze badge</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930076">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>-4</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="24 views">
#      24 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930076/is-there-any-reason-why-fstream-is-skipping-the-first-line-of-a-txt-file-in-c">Is there any reason why fstream is skipping the first line of a .txt file in C++?</a></h3>
#  <div class="excerpt">
#              I am working on a program that reads lines of string from a .txt file. I used a while loop and when just attempting to output the text into a separate .txt file the first line does not show up. Is ...
#          </div>
#  <div class="tags t-cçç">
#  <a class="post-tag" href="/questions/tagged/c%2b%2b" rel="tag" title="show questions tagged 'c++'">c++</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:38:04Z">14 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14173219/tyler-zucks"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh6.googleusercontent.com/-lVOpPRn41lc/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmJ_Aw0gyoAfz3azhExw51dNLMztA/photo.jpg?sz=32" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14173219/tyler-zucks">Tyler Zucks</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930074">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="5 views">
#      5 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930074/transform-rails-params">Transform Rails params?</a></h3>
#  <div class="excerpt">
#              Is there a way to transform Rails params?
#  I have a URL like @some-user/posts/1
#  Users have the decorated @ in the URL.
#  But, Users are saved without the @ like.. some-user
#  So I need to look up the post ...
#          </div>
#  <div class="tags t-ruby-on-rails">
#  <a class="post-tag" href="/questions/tagged/ruby-on-rails" rel="tag" title="show questions tagged 'ruby-on-rails'">ruby-on-rails</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:37:53Z">14 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/294260/gn"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/92ba886b03a595085d0410bf2546854c?s=32&amp;d=identicon&amp;r=PG" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/294260/gn">GN.</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">3,580</span><span aria-hidden="true" title="4 gold badges"><span class="badge1"></span><span class="badgecount">4</span></span><span class="v-visible-sr">4 gold badges</span><span aria-hidden="true" title="30 silver badges"><span class="badge2"></span><span class="badgecount">30</span></span><span class="v-visible-sr">30 silver badges</span><span aria-hidden="true" title="59 bronze badges"><span class="badge3"></span><span class="badgecount">59</span></span><span class="v-visible-sr">59 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930072">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>-4</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="10 views">
#      10 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930072/when-we-execute-second-time-it-should-show-the-given-value-first-time">when we execute second time it should show the given value first time? [closed]</a></h3>
#  <div class="excerpt">
#              How to store a value in a program and when we execute it second time it should show the stored value...
#  (like google assistant works......).................................................................
#          </div>
#  <div class="tags t-python-3ûx">
#  <a class="post-tag" href="/questions/tagged/python-3.x" rel="tag" title="show questions tagged 'python-3.x'">python-3.x</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:36:47Z">15 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/14291051/karthik-singaram"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://lh3.googleusercontent.com/a-/AOh14GimJPifuPwTXLVSX2JqK1xT6AWAsov-Dui3Yacu=k-s32" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/14291051/karthik-singaram">Karthik Singaram</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">1</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930068">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status answered">
#  <strong>1</strong>answer
#              </div>
#  </div>
#  <div class="views" title="11 views">
#      11 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930068/unable-to-remove-white-space-from-html-view-with-bootstrap">unable to remove white space from HTML view with Bootstrap</a></h3>
#  <div class="excerpt">
#              I'm having an issue with the template view below. I've added a scrollbar to the "Used in" table at the bottom, however I am getting a lot of whitespace underneath it. When I try removing ...
#          </div>
#  <div class="tags t-html t-css t-django t-scroll t-whitespace">
#  <a class="post-tag" href="/questions/tagged/html" rel="tag" title="show questions tagged 'html'">html</a> <a class="post-tag" href="/questions/tagged/css" rel="tag" title="show questions tagged 'css'">css</a> <a class="post-tag" href="/questions/tagged/django" rel="tag" title="show questions tagged 'django'">django</a> <a class="post-tag" href="/questions/tagged/scroll" rel="tag" title="show questions tagged 'scroll'">scroll</a> <a class="post-tag" href="/questions/tagged/whitespace" rel="tag" title="show questions tagged 'whitespace'">whitespace</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:36:05Z">16 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/3862724/foxtrotactinium"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/d4f82a79442e004178ca2bc189ff3066?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/3862724/foxtrotactinium">Foxtrotactinium</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">15</span><span aria-hidden="true" title="4 bronze badges"><span class="badge3"></span><span class="badgecount">4</span></span><span class="v-visible-sr">4 bronze badges</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="question-summary" id="question-summary-63930067">
#  <div class="statscontainer">
#  <div class="stats">
#  <div class="vote">
#  <div class="votes">
#  <span class="vote-count-post"><strong>0</strong></span>
#  <div class="viewcount">votes</div>
#  </div>
#  </div>
#  <div class="status unanswered">
#  <strong>0</strong>answers
#              </div>
#  </div>
#  <div class="views" title="5 views">
#      5 views
#  </div>
#  </div>
#  <div class="summary">
#  <h3><a class="question-hyperlink" href="/questions/63930067/future-builder-not-building">Future Builder not building</a></h3>
#  <div class="excerpt">
#              I'm trying to include Future Builder but it goes into the CircularProgressIndicator()  and doesn't load the actual screen code after the value of 'time' is populated by calling  from sharedpreferences ...
#          </div>
#  <div class="tags t-flutter t-sharedpreferences t-flutter-futurebuilder">
#  <a class="post-tag" href="/questions/tagged/flutter" rel="tag" title="show questions tagged 'flutter'">flutter</a> <a class="post-tag" href="/questions/tagged/sharedpreferences" rel="tag" title="show questions tagged 'sharedpreferences'">sharedpreferences</a> <a class="post-tag" href="/questions/tagged/flutter-futurebuilder" rel="tag" title="show questions tagged 'flutter-futurebuilder'">flutter-futurebuilder</a>
#  </div>
#  <div class="started fr">
#  <div class="user-info">
#  <div class="user-action-time">
#          asked <span class="relativetime" title="2020-09-17 01:36:04Z">16 mins ago</span>
#  </div>
#  <div class="user-gravatar32">
#  <a href="/users/13113985/int-string"><div class="gravatar-wrapper-32"><img alt="" class="bar-sm" height="32" src="https://www.gravatar.com/avatar/abf3f7d3e662a41c182edcd9abaf3a1e?s=32&amp;d=identicon&amp;r=PG&amp;f=1" width="32"/></div></a>
#  </div>
#  <div class="user-details">
#  <a href="/users/13113985/int-string">int_string</a>
#  <div class="-flair">
#  <span class="reputation-score" dir="ltr" title="reputation score ">11</span><span aria-hidden="true" title="1 bronze badge"><span class="badge3"></span><span class="badgecount">1</span></span><span class="v-visible-sr">1 bronze badge</span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
questions_data = {
    "questions": []
}

for que in questions:
    q = que.select_one('.question-hyperlink').getText()
    vote_count = que.select_one('.vote-count-post').getText()
    views = que.select_one('.views').attrs['title']
    questions_data['questions'].append({
        "question": q,
        "views": views,
        "vote_count": vote_count
    })

# %%
questions_data
# Out:
# {'questions': [{'question': 'ragged tensor to numpy or list?',
#    'views': '3 views',
#    'vote_count': '0'},
#   {'question': 'Q: MapBox Heatmap hide outside boundaries',
#    'views': '2 views',
#    'vote_count': '0'},
#   {'question': 'Python Best Practice for Looping Backwards in For Loop without reversing the array',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'Skip binding ID but return it as a response',
#    'views': '3 views',
#    'vote_count': '0'},
#   {'question': 'Using lambda to pull image from Docker hub and push to ECR',
#    'views': '3 views',
#    'vote_count': '0'},
#   {'question': 'Andron CNC data file', 'views': '3 views', 'vote_count': '0'},
#   {'question': 'How to start embedded tomcat to test spring controller, not to use @SpringBootTest?',
#    'views': '3 views',
#    'vote_count': '0'},
#   {'question': 'How do i create a sequence of number/ character with seq() and rep()',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'Join-Path AdditionalChildPath parameter deprecated or am I misusing?',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'Calculate standard deviation using R',
#    'views': '3 views',
#    'vote_count': '0'},
#   {'question': 'SQL: Column count does not match',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'python: a zero-length asyncio queue',
#    'views': '7 views',
#    'vote_count': '0'},
#   {'question': 'How to converet Readblestrem to JSON',
#    'views': '3 views',
#    'vote_count': '0'},
#   {'question': 'nesting components with createElement in React yields error',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'Pass a second value from authentication with Swashbuckle (Swagger)',
#    'views': '9 views',
#    'vote_count': '0'},
#   {'question': 'Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?',
#    'views': '6 views',
#    'vote_count': '0'},
#   {'question': 'Upload jpg with flask and html',
#    'views': '6 views',
#    'vote_count': '0'},
#   {'question': 'cURL Request Through Ajax',
#    'views': '7 views',
#    'vote_count': '-2'},
#   {'question': 'Why am I getting this invalid syntax in Dictionary using Python3?',
#    'views': '7 views',
#    'vote_count': '0'},
#   {'question': 'React Router: Link component setting href to fully qualified url instead of relative',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'I want to do user finder using python django',
#    'views': '9 views',
#    'vote_count': '0'},
#   {'question': 'How to use two different Info.plists?',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'How to accelerate product of numpy arrays in python',
#    'views': '8 views',
#    'vote_count': '0'},
#   {'question': 'Count duplicates in a row using only one cell formula (no conditional formatting either)',
#    'views': '8 views',
#    'vote_count': '0'},
#   {'question': 'How to compare objects to user input in an if statement',
#    'views': '12 views',
#    'vote_count': '0'},
#   {'question': 'Best tool/tech/ to build an GUI editor for a specific game with predefined gui binary format [closed]',
#    'views': '7 views',
#    'vote_count': '-3'},
#   {'question': 'Array in java does not change after being assigned the value of another array',
#    'views': '17 views',
#    'vote_count': '0'},
#   {'question': '.env sticked in laravel app on shared hosting',
#    'views': '8 views',
#    'vote_count': '0'},
#   {'question': "how to pass in class' non-static method into class' data member's constructor",
#    'views': '8 views',
#    'vote_count': '0'},
#   {'question': 'visjs shrink unrelated nodes - value/scale not working as expected',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'What folder to put firebase and other data-related back-end files in for Flutter applications?',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'Error: The email address is badly formatted - React-native - Firebase',
#    'views': '10 views',
#    'vote_count': '0'},
#   {'question': 'Submit form - Need JavaScript to appear without page refresh',
#    'views': '18 views',
#    'vote_count': '0'},
#   {'question': 'How does selenium-side-runner realize automatic screenshots?',
#    'views': '4 views',
#    'vote_count': '0'},
#   {'question': 'PointDNS - “Name is managed by another account” on Heroku App',
#    'views': '7 views',
#    'vote_count': '0'},
#   {'question': 'String in last line is not giving ans',
#    'views': '10 views',
#    'vote_count': '0'},
#   {'question': 'How to securely run automated paramiko ssh tasks in python when password is required?',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'What is the design pattern being used?',
#    'views': '8 views',
#    'vote_count': '-1'},
#   {'question': 'How to query data from InfluxDB using Node.js',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'How should I approach roman numeral converter? [duplicate]',
#    'views': '13 views',
#    'vote_count': '-2'},
#   {'question': 'Excel formula that returns specific lists of values?',
#    'views': '7 views',
#    'vote_count': '0'},
#   {'question': 'How do you change the data Color of a line chart in Power BI based on Slicer Selection',
#    'views': '6 views',
#    'vote_count': '0'},
#   {'question': 'Merging elements of array in scala',
#    'views': '12 views',
#    'vote_count': '0'},
#   {'question': "my app stores my token, but I can't send it to the header",
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'Is there any reason why fstream is skipping the first line of a .txt file in C++?',
#    'views': '24 views',
#    'vote_count': '-4'},
#   {'question': 'Transform Rails params?',
#    'views': '5 views',
#    'vote_count': '0'},
#   {'question': 'when we execute second time it should show the given value first time? [closed]',
#    'views': '10 views',
#    'vote_count': '-4'},
#   {'question': 'unable to remove white space from HTML view with Bootstrap',
#    'views': '11 views',
#    'vote_count': '0'},
#   {'question': 'Future Builder not building',
#    'views': '5 views',
#    'vote_count': '0'}]}

# %%
len(questions_data['questions'])
# Out:
# 50

# %%
json_data = json.dumps(questions_data)

json_data
# Out:
# '{"questions": [{"question": "ragged tensor to numpy or list?", "views": "3 views", "vote_count": "0"}, {"question": "Q: MapBox Heatmap hide outside boundaries", "views": "2 views", "vote_count": "0"}, {"question": "Python Best Practice for Looping Backwards in For Loop without reversing the array", "views": "4 views", "vote_count": "0"}, {"question": "Skip binding ID but return it as a response", "views": "3 views", "vote_count": "0"}, {"question": "Using lambda to pull image from Docker hub and push to ECR", "views": "3 views", "vote_count": "0"}, {"question": "Andron CNC data file", "views": "3 views", "vote_count": "0"}, {"question": "How to start embedded tomcat to test spring controller, not to use @SpringBootTest?", "views": "3 views", "vote_count": "0"}, {"question": "How do i create a sequence of number/ character with seq() and rep()", "views": "4 views", "vote_count": "0"}, {"question": "Join-Path AdditionalChildPath parameter deprecated or am I misusing?", "views": "5 views", "vote_count": "0"}, {"question": "Calculate standard deviation using R", "views": "3 views", "vote_count": "0"}, {"question": "SQL: Column count does not match", "views": "5 views", "vote_count": "0"}, {"question": "CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue", "views": "4 views", "vote_count": "0"}, {"question": "python: a zero-length asyncio queue", "views": "7 views", "vote_count": "0"}, {"question": "How to converet Readblestrem to JSON", "views": "3 views", "vote_count": "0"}, {"question": "nesting components with createElement in React yields error", "views": "4 views", "vote_count": "0"}, {"question": "Pass a second value from authentication with Swashbuckle (Swagger)", "views": "9 views", "vote_count": "0"}, {"question": "Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?", "views": "6 views", "vote_count": "0"}, {"question": "Upload jpg with flask and html", "views": "6 views", "vote_count": "0"}, {"question": "cURL Request Through Ajax", "views": "7 views", "vote_count": "-2"}, {"question": "Why am I getting this invalid syntax in Dictionary using Python3?", "views": "7 views", "vote_count": "0"}, {"question": "React Router: Link component setting href to fully qualified url instead of relative", "views": "4 views", "vote_count": "0"}, {"question": "I want to do user finder using python django", "views": "9 views", "vote_count": "0"}, {"question": "How to use two different Info.plists?", "views": "5 views", "vote_count": "0"}, {"question": "How to accelerate product of numpy arrays in python", "views": "8 views", "vote_count": "0"}, {"question": "Count duplicates in a row using only one cell formula (no conditional formatting either)", "views": "8 views", "vote_count": "0"}, {"question": "How to compare objects to user input in an if statement", "views": "12 views", "vote_count": "0"}, {"question": "Best tool/tech/ to build an GUI editor for a specific game with predefined gui binary format [closed]", "views": "7 views", "vote_count": "-3"}, {"question": "Array in java does not change after being assigned the value of another array", "views": "17 views", "vote_count": "0"}, {"question": ".env sticked in laravel app on shared hosting", "views": "8 views", "vote_count": "0"}, {"question": "how to pass in class\' non-static method into class\' data member\'s constructor", "views": "8 views", "vote_count": "0"}, {"question": "visjs shrink unrelated nodes - value/scale not working as expected", "views": "4 views", "vote_count": "0"}, {"question": "What folder to put firebase and other data-related back-end files in for Flutter applications?", "views": "5 views", "vote_count": "0"}, {"question": "Error: The email address is badly formatted - React-native - Firebase", "views": "10 views", "vote_count": "0"}, {"question": "Submit form - Need JavaScript to appear without page refresh", "views": "18 views", "vote_count": "0"}, {"questio ...

# %% [markdown]
# ## Test 2

# %%
res = requests.get("https://stackoverflow.com/questions?tab=newest&page=1")

# %%
soup = BeautifulSoup(res.text, "html.parser")
soup.head()
# Out:
# [<title>Newest Questions - Page 1 - Stack Overflow</title>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>,
#  <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>,
#  <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>,
#  <meta content="website" property="og:type">
#  <meta content="https://stackoverflow.com/questions?tab=newest&amp;page=1" property="og:url"/>
#  <meta content="Stack Overflow" property="og:site_name"/>
#  <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="stackoverflow.com" name="twitter:domain"/>
#  <meta content="Newest Questions - Page 1" itemprop="name" name="twitter:title" property="og:title"/>
#  <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
#  <script src="https://cdn.sstatic.net/Js/stub.en.js?v=ae62f735acf1"></script>
#  <link href="https://cdn.sstatic.net/Shared/stacks.css?v=13d89c0c9941" rel="stylesheet" type="text/css"/>
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=2a54031b08a6" rel="stylesheet" type="text/css"/>
#  <script>
#          StackExchange.init({"locale":"en","serverTime":1600307931,"routeName":"Questions/List","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"childUrl":"https://meta.stackoverflow.com","styleCodeWithHighlightjs":false,"negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"4c68b862989664dbad0abdbd8bc2e03531d90cb93092ac7983b741f8aeca92da","tid":"69f2f403-5ee5-4592-8e77-255f76f37e0e","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/svg-icons","svgIconHash":"e06df390d347"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"slack":{"sidebarAdDismissCookie":"slack-sidebar-ad","sidebarAdDismissCookieExpirationDays":60.0},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#          StackExchange.using.setCacheBreakers({"js/adops.en.js":"22a9bd59b1e9","js/ask.en.js":"83cc8cb596d5","js/begin-edit-event.en.js":"cb9965ad8784","js/events.en.js":"76e1cbcf42ae","js/explore-qlist.en.js":"4556f86d8730","js/full-anon.en.js":"fe8573dfb8a1","js/full.en.js":"38d7efd71517","js/help.en.js":"6a9178c1ea2a","js/highlightjs-loader.en.js":"76b9cf2cd902","js/inline-tag-editing.en.js":"88510a5b8778","js/keyboard-shortcuts.en.js":"c9ee7e3f5382","js/markdown-it-loader.en.js":"d0c0c5aa47f6","js/mobile.en.js":"7c56da39f21a","js/moderator.en.js":"b62ce0f34b23","js/postCollections-transpiled.en.js":"f9147073caf6","js/post-validation.en.js":"3591b67b253a","js/prettify-full.en.js":"3ff8effcec81","js/question-editor.en.js":"","js/review.en.js":"aeb8473fe536","js/revisions.en.js":"21da4c377f56","js/stacks-editor.en.js":"178ccb2d4e45","js/tageditor.en.js":"0ffdcf3fc9c4","js/tageditornew.en.js":"5b8b827ee7c9","js/tagsuggestions.en.js":"9b2c5d9791d2","js/wmd.en.js":"083f53e95f03","js/snippet-javascript-codemirror.en.js":"9e7d06feb678"});
#          StackExchange.using("gps", function() {
#               StackExchange.gps.init(true);
#          });
#      </script>
#  <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>
#  </meta>,
#  <meta content="https://stackoverflow.com/questions?tab=newest&amp;page=1" property="og:url"/>,
#  <meta content="Stack Overflow" property="og:site_name"/>,
#  <meta content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" itemprop="image primaryImageOfPage" property="og:image"/>,
#  <meta content="summary" name="twitter:card"/>,
#  <meta content="stackoverflow.com" name="twitter:domain"/>,
#  <meta content="Newest Questions - Page 1" itemprop="name" name="twitter:title" property="og:title"/>,
#  <meta content="Stack Overflow | The World’s Largest Online Community for Developers" itemprop="description" name="twitter:description" property="og:description"/>,
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>,
#  <script src="https://cdn.sstatic.net/Js/stub.en.js?v=ae62f735acf1"></script>,
#  <link href="https://cdn.sstatic.net/Shared/stacks.css?v=13d89c0c9941" rel="stylesheet" type="text/css"/>,
#  <link href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=2a54031b08a6" rel="stylesheet" type="text/css"/>,
#  <script>
#          StackExchange.init({"locale":"en","serverTime":1600307931,"routeName":"Questions/List","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack Overflow","description":"Q&A for professional and enthusiast programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"childUrl":"https://meta.stackoverflow.com","styleCodeWithHighlightjs":false,"negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"4c68b862989664dbad0abdbd8bc2e03531d90cb93092ac7983b741f8aeca92da","tid":"69f2f403-5ee5-4592-8e77-255f76f37e0e","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}},"story":{"minCompleteBodyLength":75,"likedTagsMaxLength":300,"dislikedTagsMaxLength":300},"jobPreferences":{"maxNumDeveloperRoles":2,"maxNumIndustries":4},"svgIconPath":"https://cdn.sstatic.net/Img/svg-icons","svgIconHash":"e06df390d347"}, {"userProfile":{"openGraphAPIKey":"4a307e43-b625-49bb-af15-ffadf2bda017"},"userMessaging":{"showNewFeatureNotice":true},"tags":{},"subscriptions":{"defaultMaxTrueUpSeats":1000},"snippets":{"renderDomain":"stacksnippets.net","snippetsEnabled":true},"slack":{"sidebarAdDismissCookie":"slack-sidebar-ad","sidebarAdDismissCookieExpirationDays":60.0},"site":{"allowImageUploads":true,"enableImgurHttps":true,"enableUserHovercards":true,"forceHttpsImages":true,"styleCode":true},"paths":{},"monitoring":{"clientTimingsAbsoluteTimeout":30000,"clientTimingsDebounceTimeout":1000},"mentions":{"maxNumUsersInDropdown":50},"markdown":{},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"comments":{},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true}});
#          StackExchange.using.setCacheBreakers({"js/adops.en.js":"22a9bd59b1e9","js/ask.en.js":"83cc8cb596d5","js/begin-edit-event.en.js":"cb9965ad8784","js/events.en.js":"76e1cbcf42ae","js/explore-qlist.en.js":"4556f86d8730","js/full-anon.en.js":"fe8573dfb8a1","js/full.en.js":"38d7efd71517","js/help.en.js":"6a9178c1ea2a","js/highlightjs-loader.en.js":"76b9cf2cd902","js/inline-tag-editing.en.js":"88510a5b8778","js/keyboard-shortcuts.en.js":"c9ee7e3f5382","js/markdown-it-loader.en.js":"d0c0c5aa47f6","js/mobile.en.js":"7c56da39f21a","js/moderator.en.js":"b62ce0f34b23","js/postCollections-transpiled.en.js":"f9147073caf6","js/post-validation.en.js":"3591b67b253a","js/prettify-full.en.js":"3ff8effcec81","js/question-editor.en.js":"","js/review.en.js":"aeb8473fe536","js/revisions.en.js":"21da4c377f56","js/stacks-editor.en.js":"178ccb2d4e45","js/tageditor.en.js":"0ffdcf3fc9c4","js/tageditornew.en.js":"5b8b827ee7c9","js/tagsuggestions.en.js":"9b2c5d9791d2","js/wmd.en.js":"083f53e95f03","js/snippet-javascript-codemirror.en.js":"9e7d06feb678"});
#          StackExchange.using("gps", function() {
#               StackExchange.gps.init(true);
#          });
#      </script>,
#  <noscript id="noscript-css"><style>body,.top-bar{margin-top:1.9em}</style></noscript>,
#  <style>body,.top-bar{margin-top:1.9em}</style>]

# %%
questions = soup.select(".question-summary")

questions_data = {
    "questions": []
}

for que in questions:
    q = que.select_one('.question-hyperlink').getText()
    vote_count = que.select_one('.vote-count-post').getText()
    views = que.select_one('.views').attrs['title']
    questions_data['questions'].append({
        "question": q,
        "views": views,
        "vote_count": vote_count
    })
    
json_data = json.dumps(questions_data)

json_data
# Out:
# '{"questions": [{"question": "PHP Regex - How to do str_replace on preg_replace numeric backreferences?", "views": "2 views", "vote_count": "0"}, {"question": "You can\'t run lead ads until your Facebook Page accepts Facebook\'s Lead Generation Terms of Service", "views": "2 views", "vote_count": "0"}, {"question": "Is FILE * reassignment without fclose() okay?", "views": "3 views", "vote_count": "0"}, {"question": "call stored procedure in python using cursor", "views": "2 views", "vote_count": "0"}, {"question": "how to separate a text as a list in classic asp", "views": "2 views", "vote_count": "0"}, {"question": "How do you host a domain that was purchased through google domains on apache2 in linux", "views": "2 views", "vote_count": "0"}, {"question": "Vuetify Tabs as Nested dynamic routes erroring on parent prop", "views": "2 views", "vote_count": "0"}, {"question": "Create \\u201cKnockout Text\\u201d effect using SVG paths", "views": "4 views", "vote_count": "0"}, {"question": "Using TOAST UI editor, I cannot upload image that has a over 50kb", "views": "3 views", "vote_count": "0"}, {"question": "Game that doesn\'t stop", "views": "2 views", "vote_count": "0"}, {"question": "Google Home Control Fan", "views": "3 views", "vote_count": "0"}, {"question": "Getting error resolveBackend is not a function", "views": "3 views", "vote_count": "0"}, {"question": "how to resolve the CAMERA_UNAVAILABLE problem", "views": "6 views", "vote_count": "0"}, {"question": "Efficiency of return statement", "views": "9 views", "vote_count": "0"}, {"question": "Modifying an array of object and arrays. to sort the objects based on matching values", "views": "6 views", "vote_count": "0"}, {"question": "Tic Tac Toe Array Check Game over", "views": "8 views", "vote_count": "0"}, {"question": "What does \\u201c..\\\\\\\\..\\\\\\\\Tools\\\\\\\\GFuel\\\\\\\\Guel.exe\\u201d signify?", "views": "6 views", "vote_count": "0"}, {"question": "AWS Lambda times out on 30 seconds even though timeout configured to be 2 minutes", "views": "4 views", "vote_count": "0"}, {"question": "os.join.path does change directory", "views": "6 views", "vote_count": "0"}, {"question": "Index strings coming up with a programing following the questions below (python)", "views": "5 views", "vote_count": "0"}, {"question": "tslint,codelyzer warning should failed build", "views": "4 views", "vote_count": "0"}, {"question": "generate input function for tf.estimator takes infinite loading", "views": "4 views", "vote_count": "0"}, {"question": "GPIO pin needs to be enabled on boot to recognize flash chip", "views": "4 views", "vote_count": "0"}, {"question": "How can I turn a large integer into an array of successive two-digit integers?", "views": "13 views", "vote_count": "0"}, {"question": "Ajax disabling button when there\'s no value from database on readonly form", "views": "4 views", "vote_count": "0"}, {"question": "UISearchController does not show up in iOS 12", "views": "5 views", "vote_count": "0"}, {"question": "How to get different image on different screen size in bootstrap 3 carousel, for local hosted images", "views": "4 views", "vote_count": "0"}, {"question": "ragged tensor to numpy or list?", "views": "6 views", "vote_count": "-1"}, {"question": "MapBox Heatmap hide outside boundaries", "views": "7 views", "vote_count": "0"}, {"question": "Python Best Practice for Looping Backwards in For Loop without reversing the array", "views": "16 views", "vote_count": "0"}, {"question": "Skip binding ID but return it as a response", "views": "6 views", "vote_count": "0"}, {"question": "Using lambda to pull image from Docker hub and push to ECR", "views": "5 views", "vote_count": "0"}, {"question": "Andron CNC data file", "views": "6 views", "vote_count": "0"}, {"question": "How to start embedded tomcat to test spring controller, not to use @SpringBootTest?", "views": "4 views", "vote_count": "0"}, {"question": "How do i create a sequence of number/ character with seq() and  ...

# %%
len(questions_data['questions'])
# Out:
# 50

# %%
questions_data = {
    "questions": []
}

# %%
for i in range(100):
    
    link = 'https://stackoverflow.com/questions?tab=newest&page=' + str(i)
    
    print(link)
    res = requests.get(link)
    soup = BeautifulSoup(res.text, "html.parser")
    questions = soup.select(".question-summary")
    
    for que in questions:
        q = que.select_one('.question-hyperlink').getText()
        vote_count = que.select_one('.vote-count-post').getText()
        views = que.select_one('.views').attrs['title']
        questions_data['questions'].append({
            "question": q,
            "views": views,
            "vote_count": vote_count
        })
# Out:
# https://stackoverflow.com/questions?tab=newest&page=0
# https://stackoverflow.com/questions?tab=newest&page=1
# https://stackoverflow.com/questions?tab=newest&page=2
# https://stackoverflow.com/questions?tab=newest&page=3
# https://stackoverflow.com/questions?tab=newest&page=4
# https://stackoverflow.com/questions?tab=newest&page=5
# https://stackoverflow.com/questions?tab=newest&page=6
# https://stackoverflow.com/questions?tab=newest&page=7
# https://stackoverflow.com/questions?tab=newest&page=8
# https://stackoverflow.com/questions?tab=newest&page=9
# https://stackoverflow.com/questions?tab=newest&page=10
# https://stackoverflow.com/questions?tab=newest&page=11
# https://stackoverflow.com/questions?tab=newest&page=12
# https://stackoverflow.com/questions?tab=newest&page=13
# https://stackoverflow.com/questions?tab=newest&page=14
# https://stackoverflow.com/questions?tab=newest&page=15
# https://stackoverflow.com/questions?tab=newest&page=16
# https://stackoverflow.com/questions?tab=newest&page=17
# https://stackoverflow.com/questions?tab=newest&page=18
# https://stackoverflow.com/questions?tab=newest&page=19
# https://stackoverflow.com/questions?tab=newest&page=20
# https://stackoverflow.com/questions?tab=newest&page=21
# https://stackoverflow.com/questions?tab=newest&page=22
# https://stackoverflow.com/questions?tab=newest&page=23
# https://stackoverflow.com/questions?tab=newest&page=24
# https://stackoverflow.com/questions?tab=newest&page=25
# https://stackoverflow.com/questions?tab=newest&page=26
# https://stackoverflow.com/questions?tab=newest&page=27
# https://stackoverflow.com/questions?tab=newest&page=28
# https://stackoverflow.com/questions?tab=newest&page=29
# https://stackoverflow.com/questions?tab=newest&page=30
# https://stackoverflow.com/questions?tab=newest&page=31
# https://stackoverflow.com/questions?tab=newest&page=32
# https://stackoverflow.com/questions?tab=newest&page=33
# https://stackoverflow.com/questions?tab=newest&page=34
# https://stackoverflow.com/questions?tab=newest&page=35
# https://stackoverflow.com/questions?tab=newest&page=36
# https://stackoverflow.com/questions?tab=newest&page=37
# https://stackoverflow.com/questions?tab=newest&page=38
# https://stackoverflow.com/questions?tab=newest&page=39
# https://stackoverflow.com/questions?tab=newest&page=40
# https://stackoverflow.com/questions?tab=newest&page=41
# https://stackoverflow.com/questions?tab=newest&page=42
# https://stackoverflow.com/questions?tab=newest&page=43
# https://stackoverflow.com/questions?tab=newest&page=44
# https://stackoverflow.com/questions?tab=newest&page=45
# https://stackoverflow.com/questions?tab=newest&page=46
# https://stackoverflow.com/questions?tab=newest&page=47
# https://stackoverflow.com/questions?tab=newest&page=48
# https://stackoverflow.com/questions?tab=newest&page=49
# https://stackoverflow.com/questions?tab=newest&page=50
# https://stackoverflow.com/questions?tab=newest&page=51
# https://stackoverflow.com/questions?tab=newest&page=52
# https://stackoverflow.com/questions?tab=newest&page=53
# https://stackoverflow.com/questions?tab=newest&page=54
# https://stackoverflow.com/questions?tab=newest&page=55
# https://stackoverflow.com/questions?tab=newest&page=56
# https://stackoverflow.com/questions?tab=newest&page=57
# https://stackoverflow.com/questions?tab=newest&page=58
# https://stackoverflow.com/questions?tab=newest&page=59
# https://stackoverflow.com/questions?tab=newest&page=60
# https://stackoverflow.com/questions?tab=newest&page=61
# https://stackoverflow.com/questions?tab=newest&page=62
# https://stackoverflow.com/questions?tab=newest&page=63
# https://stackoverflow.com/questions?tab=newest&page=64
# https://stackoverflow.com/questions?tab=newest&page=65
# https://stackoverflow.com/questions?tab=newest&page=66
# https://stackoverflow.com/questions?tab=newest&page=67
# https://stackoverflow.com/questions?tab=newest&page=68
# https://stackoverflow.com/questions?tab=newest&page=69
# https://stackoverflow.com/questions?tab=newest&page=70
# https://stackoverflow.com/questions?tab=newest&page=71
# https://stackoverflow.com/questions?tab=newest&page=72
# https://stackoverflow.com/questions?tab=newest&page=73
# https://stackoverflow.com/questions?tab=newest&page=74
# https://stackoverflow.com/questions?tab=newest&page=75
# https://stackoverflow.com/questions?tab=newest&page=76
# https://stackoverflow.com/questions?tab=newest&page=77
# https://stackoverflow.com/questions?tab=newest&page=78
# https://stackoverflow.com/questions?tab=newest&page=79
# https://stackoverflow.com/questions?tab=newest&page=80
# https://stackoverflow.com/questions?tab=newest&page=81
# https://stackoverflow.com/questions?tab=newest&page=82
# https://stackoverflow.com/questions?tab=newest&page=83
# https://stackoverflow.com/questions?tab=newest&page=84
# https://stackoverflow.com/questions?tab=newest&page=85
# https://stackoverflow.com/questions?tab=newest&page=86
# https://stackoverflow.com/questions?tab=newest&page=87
# https://stackoverflow.com/questions?tab=newest&page=88
# https://stackoverflow.com/questions?tab=newest&page=89
# https://stackoverflow.com/questions?tab=newest&page=90
# https://stackoverflow.com/questions?tab=newest&page=91
# https://stackoverflow.com/questions?tab=newest&page=92
# https://stackoverflow.com/questions?tab=newest&page=93
# https://stackoverflow.com/questions?tab=newest&page=94
# https://stackoverflow.com/questions?tab=newest&page=95
# https://stackoverflow.com/questions?tab=newest&page=96
# https://stackoverflow.com/questions?tab=newest&page=97
# https://stackoverflow.com/questions?tab=newest&page=98
# https://stackoverflow.com/questions?tab=newest&page=99

# %%
len(questions_data['questions'])
# Out:
# 5150

# %%
questions_data['questions']
# Out:
# [{'question': "jquery ajax - There's an error when I use the jsonp",
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'Form validation of Select2',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'How to make WinForm run in background / hide it from TaskManager/Apps',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'If value matches vector in data.frame, return the value in adjacent column',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'CLion not showing any symbols when working with Unreal Engine 4.25',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'PHP Regex - How to do str_replace on preg_replace numeric backreferences?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': "You can't run lead ads until your Facebook Page accepts Facebook's Lead Generation Terms of Service",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Is FILE * reassignment without fclose() okay?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'call stored procedure in python using cursor',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'how to separate a text as a list in classic asp',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How do you host a domain that was purchased through google domains on apache2 in linux',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Vuetify Tabs as Nested dynamic routes erroring on parent prop',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Create “Knockout Text” effect using SVG paths',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Using TOAST UI editor, I cannot upload image that has a over 50kb',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': "Game that doesn't stop", 'views': '5 views', 'vote_count': '0'},
#  {'question': 'Google Home Control Fan',
#   'views': '6 views',
#   'vote_count': '-1'},
#  {'question': 'Getting error resolveBackend is not a function',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'how to resolve the CAMERA_UNAVAILABLE problem',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Efficiency of return statement',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'Modifying an array of objects and arrays. to sort the objects based on matching values within the array',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Tic Tac Toe Array Check Game over',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'What does “..\\\\..\\\\Tools\\\\GFuel\\\\Guel.exe” signify?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'AWS Lambda times out on 30 seconds even though timeout configured to be 2 minutes',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'os.join.path does change directory',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Index strings coming up with a programing following the questions below (python) [closed]',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'tslint,codelyzer warning should failed build',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'generate input function for tf.estimator takes infinite loading',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'GPIO pin needs to be enabled on boot to recognize flash chip',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How can I turn a large integer into an array of successive two-digit integers?',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': "Ajax disabling button when there's no value from database on readonly form",
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'UISearchController does not show up in iOS 12',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to get different image on different screen size in bootstrap 3 carousel, for local hosted images',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'ragged tensor to numpy or list?',
#   'views': '7 views',
#   'vote_count': '-1'},
#  {'question': 'MapBox Heatmap hide outside boundaries',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Python Best Practice for Looping Backwards in For Loop without reversing the array',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Skip binding ID but return it as a response',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Using lambda to pull image from Docker hub and push to ECR',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Andron CNC data file', 'views': '6 views', 'vote_count': '0'},
#  {'question': 'How to start embedded tomcat to test spring controller, not to use @SpringBootTest?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How do i create a sequence of number/ character with seq() and rep()',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'Join-Path AdditionalChildPath parameter deprecated or am I misusing?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Calculate standard deviation using R',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'SQL: Column count does not match',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'python: a zero-length asyncio queue',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'nesting components with createElement in React yields error',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Pass a second value from authentication with Swashbuckle (Swagger)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Upload jpg with flask and html',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'cURL Request Through Ajax',
#   'views': '8 views',
#   'vote_count': '-2'},
#  {'question': "jquery ajax - There's an error when I use the jsonp",
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'Form validation of Select2',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'How to make WinForm run in background / hide it from TaskManager/Apps',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'If value matches vector in data.frame, return the value in adjacent column',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'CLion not showing any symbols when working with Unreal Engine 4.25',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'PHP Regex - How to do str_replace on preg_replace numeric backreferences?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': "You can't run lead ads until your Facebook Page accepts Facebook's Lead Generation Terms of Service",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Is FILE * reassignment without fclose() okay?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'call stored procedure in python using cursor',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'how to separate a text as a list in classic asp',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How do you host a domain that was purchased through google domains on apache2 in linux',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Vuetify Tabs as Nested dynamic routes erroring on parent prop',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Create “Knockout Text” effect using SVG paths',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Using TOAST UI editor, I cannot upload image that has a over 50kb',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': "Game that doesn't stop", 'views': '5 views', 'vote_count': '0'},
#  {'question': 'Google Home Control Fan',
#   'views': '6 views',
#   'vote_count': '-1'},
#  {'question': 'Getting error resolveBackend is not a function',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'how to resolve the CAMERA_UNAVAILABLE problem',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Efficiency of return statement',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'Modifying an array of objects and arrays. to sort the objects based on matching values within the array',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Tic Tac Toe Array Check Game over',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'What does “..\\\\..\\\\Tools\\\\GFuel\\\\Guel.exe” signify?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'AWS Lambda times out on 30 seconds even though timeout configured to be 2 minutes',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'os.join.path does change directory',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Index strings coming up with a programing following the questions below (python) [closed]',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'tslint,codelyzer warning should failed build',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'generate input function for tf.estimator takes infinite loading',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'GPIO pin needs to be enabled on boot to recognize flash chip',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How can I turn a large integer into an array of successive two-digit integers?',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': "Ajax disabling button when there's no value from database on readonly form",
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'UISearchController does not show up in iOS 12',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to get different image on different screen size in bootstrap 3 carousel, for local hosted images',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'ragged tensor to numpy or list?',
#   'views': '7 views',
#   'vote_count': '-1'},
#  {'question': 'MapBox Heatmap hide outside boundaries',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Python Best Practice for Looping Backwards in For Loop without reversing the array',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Skip binding ID but return it as a response',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Using lambda to pull image from Docker hub and push to ECR',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Andron CNC data file', 'views': '6 views', 'vote_count': '0'},
#  {'question': 'How to start embedded tomcat to test spring controller, not to use @SpringBootTest?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How do i create a sequence of number/ character with seq() and rep()',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'Join-Path AdditionalChildPath parameter deprecated or am I misusing?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Calculate standard deviation using R',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'SQL: Column count does not match',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'python: a zero-length asyncio queue',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'nesting components with createElement in React yields error',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Pass a second value from authentication with Swashbuckle (Swagger)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Upload jpg with flask and html',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'cURL Request Through Ajax',
#   'views': '8 views',
#   'vote_count': '-2'},
#  {'question': 'Why am I getting this invalid syntax in Dictionary using Python3?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'React Router: Link component setting href to fully qualified url instead of relative',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'I want to do user finder using python django',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How to use two different Info.plists?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'How to accelerate product of numpy arrays in python',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Count duplicates in a row using only one cell formula (no conditional formatting either)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How to compare objects to user input in an if statement',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Best tool/tech/ to build an GUI editor for a specific game with predefined gui binary format [closed]',
#   'views': '8 views',
#   'vote_count': '-3'},
#  {'question': 'Array in java does not change after being assigned the value of another array',
#   'views': '18 views',
#   'vote_count': '-1'},
#  {'question': 'config sticked in laravel app on shared hosting',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': "how to pass in class' non-static method into class' data member's constructor",
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'visjs shrink unrelated nodes - value/scale not working as expected',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'What folder to put firebase and other data-related back-end files in for Flutter applications?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Error: The email address is badly formatted - React-native - Firebase',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Submit form - Need JavaScript to appear without page refresh',
#   'views': '20 views',
#   'vote_count': '0'},
#  {'question': 'How does selenium-side-runner realize automatic screenshots?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'PointDNS - “Name is managed by another account” on Heroku App',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'String in last line is not giving ans [duplicate]',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'How to securely run automated paramiko ssh tasks in python when password is required?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'What is the design pattern being used?',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'How to query data from InfluxDB using Node.js',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Excel formula that returns specific lists of values?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'How do you change the data Color of a line chart in Power BI based on Slicer Selection',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Merging elements of array in scala',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': "my app stores my token, but I can't send it to the header",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Transform Rails params?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'when we execute second time it should show the given value first time? [closed]',
#   'views': '11 views',
#   'vote_count': '-4'},
#  {'question': 'unable to remove white space from HTML view with Bootstrap',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Future Builder not building',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Chartjs not appearing when sending data to PostgreSQL',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to make typeORM find query and realtions together',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Pitest does not create XML report even with the given XML option',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Jest not printing detailed stack trace of failure',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'error message when calculating descriptive statistics',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'Using CoreData managedContext from background thread…how do you do it correctly?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Using Vue in chrome extension yields blank page',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'How to archive certain rows to another sheet',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Node.js/Express authorization through Passport.js or Auth0',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'import project into qt creator but source tree is empty',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Why does k8s wordpress and mysql example use headless service for wordpress-mysql?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'ML.NET Schema mismatch: expected VarVector<Byte> got Vector<Byte>',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Can Cosmos DB V3 handle FeatureCollection GeoJson objects?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Why is my Flux query in Grafana not sorting by default?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Why is there extra white space on top and bottom of my text that has a font-size declared to it?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'How can I capture a window without showing it, minimized [closed]',
#   'views': '15 views',
#   'vote_count': '0'},
#  {'question': 'C depth-first-search - how to handle not enough file pointers being available?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': "In HTML it doesn't allow me to add vedios from my computer(.mp4). However way I try",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How do I group two time interval columns into discernible months?',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'C# Dynamic Typing in Method Returning List of Classes Throwing Constructor Not Found Error',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'I cannot find the reason as to why the do while loop is not working. It executes without checking if statement is true',
#   'views': '24 views',
#   'vote_count': '-1'},
#  {'question': "jquery ajax - There's an error when I use the jsonp",
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'Form validation of Select2',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'How to make WinForm run in background / hide it from TaskManager/Apps',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'If value matches vector in data.frame, return the value in adjacent column',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'CLion not showing any symbols when working with Unreal Engine 4.25',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'PHP Regex - How to do str_replace on preg_replace numeric backreferences?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': "You can't run lead ads until your Facebook Page accepts Facebook's Lead Generation Terms of Service",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Is FILE * reassignment without fclose() okay?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'call stored procedure in python using cursor',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'how to separate a text as a list in classic asp',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How do you host a domain that was purchased through google domains on apache2 in linux',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Vuetify Tabs as Nested dynamic routes erroring on parent prop',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Create “Knockout Text” effect using SVG paths',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Using TOAST UI editor, I cannot upload image that has a over 50kb',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': "Game that doesn't stop", 'views': '5 views', 'vote_count': '0'},
#  {'question': 'Google Home Control Fan',
#   'views': '6 views',
#   'vote_count': '-1'},
#  {'question': 'Getting error resolveBackend is not a function',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'how to resolve the CAMERA_UNAVAILABLE problem',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Efficiency of return statement',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'Modifying an array of objects and arrays. to sort the objects based on matching values within the array',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Tic Tac Toe Array Check Game over',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'What does “..\\\\..\\\\Tools\\\\GFuel\\\\Guel.exe” signify?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'AWS Lambda times out on 30 seconds even though timeout configured to be 2 minutes',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'os.join.path does change directory',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Index strings coming up with a programing following the questions below (python) [closed]',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'tslint,codelyzer warning should failed build',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'generate input function for tf.estimator takes infinite loading',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'GPIO pin needs to be enabled on boot to recognize flash chip',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How can I turn a large integer into an array of successive two-digit integers?',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': "Ajax disabling button when there's no value from database on readonly form",
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'UISearchController does not show up in iOS 12',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to get different image on different screen size in bootstrap 3 carousel, for local hosted images',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'ragged tensor to numpy or list?',
#   'views': '7 views',
#   'vote_count': '-1'},
#  {'question': 'MapBox Heatmap hide outside boundaries',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Python Best Practice for Looping Backwards in For Loop without reversing the array',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Skip binding ID but return it as a response',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Using lambda to pull image from Docker hub and push to ECR',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Andron CNC data file', 'views': '6 views', 'vote_count': '0'},
#  {'question': 'How to start embedded tomcat to test spring controller, not to use @SpringBootTest?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How do i create a sequence of number/ character with seq() and rep()',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'Join-Path AdditionalChildPath parameter deprecated or am I misusing?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Calculate standard deviation using R',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'SQL: Column count does not match',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'python: a zero-length asyncio queue',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'nesting components with createElement in React yields error',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Pass a second value from authentication with Swashbuckle (Swagger)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Upload jpg with flask and html',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'cURL Request Through Ajax',
#   'views': '8 views',
#   'vote_count': '-2'},
#  {'question': "jquery ajax - There's an error when I use the jsonp",
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'Form validation of Select2',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'How to make WinForm run in background / hide it from TaskManager/Apps',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'If value matches vector in data.frame, return the value in adjacent column',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'CLion not showing any symbols when working with Unreal Engine 4.25',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'PHP Regex - How to do str_replace on preg_replace numeric backreferences?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': "You can't run lead ads until your Facebook Page accepts Facebook's Lead Generation Terms of Service",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Is FILE * reassignment without fclose() okay?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'call stored procedure in python using cursor',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'how to separate a text as a list in classic asp',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How do you host a domain that was purchased through google domains on apache2 in linux',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Vuetify Tabs as Nested dynamic routes erroring on parent prop',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Create “Knockout Text” effect using SVG paths',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Using TOAST UI editor, I cannot upload image that has a over 50kb',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': "Game that doesn't stop", 'views': '5 views', 'vote_count': '0'},
#  {'question': 'Google Home Control Fan',
#   'views': '6 views',
#   'vote_count': '-1'},
#  {'question': 'Getting error resolveBackend is not a function',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'how to resolve the CAMERA_UNAVAILABLE problem',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Efficiency of return statement',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'Modifying an array of objects and arrays. to sort the objects based on matching values within the array',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Tic Tac Toe Array Check Game over',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'What does “..\\\\..\\\\Tools\\\\GFuel\\\\Guel.exe” signify?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'AWS Lambda times out on 30 seconds even though timeout configured to be 2 minutes',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'os.join.path does change directory',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Index strings coming up with a programing following the questions below (python) [closed]',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'tslint,codelyzer warning should failed build',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'generate input function for tf.estimator takes infinite loading',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'GPIO pin needs to be enabled on boot to recognize flash chip',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How can I turn a large integer into an array of successive two-digit integers?',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': "Ajax disabling button when there's no value from database on readonly form",
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'UISearchController does not show up in iOS 12',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to get different image on different screen size in bootstrap 3 carousel, for local hosted images',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'ragged tensor to numpy or list?',
#   'views': '7 views',
#   'vote_count': '-1'},
#  {'question': 'MapBox Heatmap hide outside boundaries',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Python Best Practice for Looping Backwards in For Loop without reversing the array',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Skip binding ID but return it as a response',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Using lambda to pull image from Docker hub and push to ECR',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Andron CNC data file', 'views': '6 views', 'vote_count': '0'},
#  {'question': 'How to start embedded tomcat to test spring controller, not to use @SpringBootTest?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How do i create a sequence of number/ character with seq() and rep()',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'Join-Path AdditionalChildPath parameter deprecated or am I misusing?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Calculate standard deviation using R',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'SQL: Column count does not match',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'CSS loading slow and causing temporary weird formatting on Laravel app with Blade and Vue',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'python: a zero-length asyncio queue',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'nesting components with createElement in React yields error',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Pass a second value from authentication with Swashbuckle (Swagger)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Is there a way to have a timer bean @Schedule method execute on single Glassfish instance instead of all of them?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Upload jpg with flask and html',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'cURL Request Through Ajax',
#   'views': '8 views',
#   'vote_count': '-2'},
#  {'question': 'Why am I getting this invalid syntax in Dictionary using Python3?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'React Router: Link component setting href to fully qualified url instead of relative',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'I want to do user finder using python django',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How to use two different Info.plists?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'How to accelerate product of numpy arrays in python',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Count duplicates in a row using only one cell formula (no conditional formatting either)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How to compare objects to user input in an if statement',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Best tool/tech/ to build an GUI editor for a specific game with predefined gui binary format [closed]',
#   'views': '8 views',
#   'vote_count': '-3'},
#  {'question': 'Array in java does not change after being assigned the value of another array',
#   'views': '18 views',
#   'vote_count': '-1'},
#  {'question': 'config sticked in laravel app on shared hosting',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': "how to pass in class' non-static method into class' data member's constructor",
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'visjs shrink unrelated nodes - value/scale not working as expected',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'What folder to put firebase and other data-related back-end files in for Flutter applications?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Error: The email address is badly formatted - React-native - Firebase',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Submit form - Need JavaScript to appear without page refresh',
#   'views': '20 views',
#   'vote_count': '0'},
#  {'question': 'How does selenium-side-runner realize automatic screenshots?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'PointDNS - “Name is managed by another account” on Heroku App',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'String in last line is not giving ans [duplicate]',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'How to securely run automated paramiko ssh tasks in python when password is required?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'What is the design pattern being used?',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'How to query data from InfluxDB using Node.js',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Excel formula that returns specific lists of values?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'How do you change the data Color of a line chart in Power BI based on Slicer Selection',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Merging elements of array in scala',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': "my app stores my token, but I can't send it to the header",
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Transform Rails params?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'when we execute second time it should show the given value first time? [closed]',
#   'views': '11 views',
#   'vote_count': '-4'},
#  {'question': 'unable to remove white space from HTML view with Bootstrap',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Future Builder not building',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Chartjs not appearing when sending data to PostgreSQL',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to make typeORM find query and realtions together',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Pitest does not create XML report even with the given XML option',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Jest not printing detailed stack trace of failure',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'error message when calculating descriptive statistics',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'Using CoreData managedContext from background thread…how do you do it correctly?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Using Vue in chrome extension yields blank page',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'How to archive certain rows to another sheet',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Node.js/Express authorization through Passport.js or Auth0',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'import project into qt creator but source tree is empty',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Why does k8s wordpress and mysql example use headless service for wordpress-mysql?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'ML.NET Schema mismatch: expected VarVector<Byte> got Vector<Byte>',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Can Cosmos DB V3 handle FeatureCollection GeoJson objects?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Why is my Flux query in Grafana not sorting by default?',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Why is there extra white space on top and bottom of my text that has a font-size declared to it?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'How can I capture a window without showing it, minimized [closed]',
#   'views': '15 views',
#   'vote_count': '0'},
#  {'question': 'C depth-first-search - how to handle not enough file pointers being available?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': "In HTML it doesn't allow me to add vedios from my computer(.mp4). However way I try",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How do I group two time interval columns into discernible months?',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'C# Dynamic Typing in Method Returning List of Classes Throwing Constructor Not Found Error',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'I cannot find the reason as to why the do while loop is not working. It executes without checking if statement is true',
#   'views': '24 views',
#   'vote_count': '-1'},
#  {'question': 'Branch Policy with path restrictions in Azure DevOps',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': "IOS: Why can't i get this Http Post Request to work?",
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'Does AWS Log that a message was move to SQS DLQ',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How Do I Retrieve Tweets from a Particular Country?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'CloudFormation create EC2 specify subnet',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'AWS console is inaccessible, the website is down',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Need help iterating through a nested list but',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'How to use babel or jsconfig to import my react components only by name',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'How can I get right encoding of a string? [duplicate]',
#   'views': '20 views',
#   'vote_count': '0'},
#  {'question': 'IONIC 5 Cordova Plugin can build but not working when run android. It work only in -livereload',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Can I get the data from my seller account in lazada and seller account in shopee? [closed]',
#   'views': '10 views',
#   'vote_count': '-3'},
#  {'question': 'Google sign in “Choose an account to continue” loop',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Scala accessing members of runtime types using reflection of a class that extends a trait',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'Problem Setting Up AJAX Request in Wordpress (with JQuery)',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'OkHttp response 204 with content-type json',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': "Dynamic pipe in angular 10 cant inject 'number' pipe",
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Python Unit Test Replace Class with Fake',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Python mock.patch is not mocking my function?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': '“Array has incomplete element type” error',
#   'views': '16 views',
#   'vote_count': '0'},
#  {'question': 'Count same entrys in a column of a csv whit Javascript [closed]',
#   'views': '10 views',
#   'vote_count': '-1'},
#  {'question': 'Does someone know how to make this type of program in java generics?',
#   'views': '26 views',
#   'vote_count': '0'},
#  {'question': 'Why i can jump and than walk, and not walk and than jump. I don´t know what is wrong with the code',
#   'views': '16 views',
#   'vote_count': '0'},
#  {'question': 'COPY from stdin PostgreSQL',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Python rounding issue need to round half up every single digit',
#   'views': '21 views',
#   'vote_count': '-1'},
#  {'question': 'Why would opening the dev tools cause javascript DOM manipulation to execute faster?',
#   'views': '22 views',
#   'vote_count': '0'},
#  {'question': 'Lodash - create new object with undefined values',
#   'views': '11 views',
#   'vote_count': '-3'},
#  {'question': 'Unable to upload file to S3 using a pre-signed URL',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Move an item from a list and remove it from the previous one in the same for each',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Obj-C - All Map Annotations not always showing on MapView?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Calculating Big “O” for the following example',
#   'views': '15 views',
#   'vote_count': '0'},
#  {'question': 'C++ Function Calling with Parameter in int main',
#   'views': '38 views',
#   'vote_count': '-3'},
#  {'question': 'Trouble Selecting Table View Rows',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'System.webserver has invalid child element “cors”',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How does a distributed LRU cache evict entries properly when using read replicas',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Flutter looking AndroidManifest.xml from wrong path',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Is there any way to extract contacts and mails from my email account programmatically? [closed]',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'How to map Hibernate custom wrapper object with ManyToMany Relationship?',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Div element slides down from the top of the html body when applying CSS transition',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'How to Deobfuscate This Lua scripts',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'How to show a general purpose dialog on demand',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'RHEL upgrade to next release | how to tie the minor version',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How to sort buckets in Elasticsearch aggregation response using the olivere/elastic library',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'How can I look up a static variable in a function with lldb?',
#   'views': '16 views',
#   'vote_count': '2'},
#  {'question': 'Processing Shared Work Queue Using CUDA Atomic Operations and Grid Synchronization',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'What should be the contents of a callback function of a google login in a react app?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'How to use React Native with a Node backend?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'React Change Navbar color on specific page using React Helmet?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': "My code won't allow the user quit, my answers aren't working right, neither will my .toLowerCase() and it also goes into an infinite loop",
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': 'EntityFramework and using a specific Database',
#   'views': '15 views',
#   'vote_count': '0'},
#  {'question': 'I want to know the definition of BNF EBNF',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Can one NiFi node have multiple host names?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': '<b-form-file> does not keep the filename visible when switched to other components',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'SQL count ocurrences on other rows with common field values',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Automatically populate integral equations depending on the bounds given',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Create functions inside Shiny Server with UI(input$NAME) as input for the function',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'snowflake parquet load schema generation',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'ADACOS implementataion on colab TPU throws error',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'JDA quzzing system using reactions: checking answers using if-then statements',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'res.render and express.static - folder navigation',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Is there a simple way to fork a server process in sbt before starting test against that server?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Pycharm error 2 (no such file) despite file existing',
#   'views': '22 views',
#   'vote_count': '0'},
#  {'question': 'How to drop row at certain index in every group in GroupBy object?',
#   'views': '22 views',
#   'vote_count': '2'},
#  {'question': 'Adding data to JSON file',
#   'views': '20 views',
#   'vote_count': '0'},
#  {'question': 'Re-selecting value and calc but old result displays in JS [closed]',
#   'views': '14 views',
#   'vote_count': '-1'},
#  {'question': 'Python Framework to Read a Image',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Trying to write a generic Makefile the I get Implicit rule search has not been done',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Extract different set of keys for different nesting level of json',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'AWS Glue write_dynamic_frame_from_options encounters schema exception',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': "Probleme with reportlab : text = text.decode('utf-8') AttributeError: 'float' object has no attribute 'decode' [closed]",
#   'views': '8 views',
#   'vote_count': '-1'},
#  {'question': 'How to draw line graph that has min-y, max-y, x value using Chartjs',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'List to nested list by a field',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'How to use multiple source files in python [closed]',
#   'views': '16 views',
#   'vote_count': '-5'},
#  {'question': 'Not able to print value of an array while using inheritance in C#',
#   'views': '21 views',
#   'vote_count': '-2'},
#  {'question': 'React - state like list is losing value',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Java: How to define equals and hashCode when inheriting from superclass?',
#   'views': '22 views',
#   'vote_count': '0'},
#  {'question': 'why index not built after successful create index in postgresql?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Split values in a column into multiple columns Tsql',
#   'views': '7 views',
#   'vote_count': '-1'},
#  {'question': 'Global objects in C# ASP.Net - always null when read back',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'Pygame Not Playing Sound on Raspberry Pi',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Define type on dynamically built object against its expected type',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'intermittent problem with automatic file upload',
#   'views': '13 views',
#   'vote_count': '0'},
#  {'question': 'Labelimg crashes when attempting to export YOLO training samples',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'How prevent Keyring from popping up in Ubuntu 16?',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'ListView groupby and also preserve original items',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Difference between methods from Thread class and methods used with Thread.currentThread()?',
#   'views': '24 views',
#   'vote_count': '1'},
#  {'question': 'react scripts for build',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Can I use nested query in granting column access control of Redshift?',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Store timestamp to BigQuery with specific timezone',
#   'views': '13 views',
#   'vote_count': '1'},
#  {'question': 'Elapsed Time for Minutes and Seconds Not Working',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'Get request URL in Arduino web server',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Getting a file from user input and store integers into array',
#   'views': '16 views',
#   'vote_count': '0'},
#  {'question': 'How would you have independent sibling height using flex/grid/table when height changes?',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Best RL algorithm to learn to play Catan [closed]',
#   'views': '7 views',
#   'vote_count': '-2'},
#  {'question': 'Spring Cloud Stream rabbit binder causing circular dependency error when using connection-prefix property',
#   'views': '5 views',
# ...
#   'views': '19 views',
#   'vote_count': '-1'},
#  {'question': 'Microsoft Addin app.config.xml for enforceFIPSPolicy does not seem to work',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': "Hitting Enter for Default Button in ASPX Doesn't Work but Mouse Does on IIS 6.2",
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Snowflake: Sqlalchemy ORM update variant field',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'jquery “clear” value in select box',
#   'views': '25 views',
#   'vote_count': '0'},
#  {'question': 'Does version control software save game files on Unity or just source code? [closed]',
#   'views': '16 views',
#   'vote_count': '-3'},
#  {'question': 'array.map issue with state',
#   'views': '23 views',
#   'vote_count': '-1'},
#  {'question': 'Groupby, transpose, or even pivot_table with pandas',
#   'views': '24 views',
#   'vote_count': '0'},
#  {'question': 'How to setup MySQL on MacOS (Getting Started)',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'sort out column of pandas dataframe by highest negative values first',
#   'views': '15 views',
#   'vote_count': '-1'},
#  {'question': 'How to select most recent Invoice Date by Business Account using BQL/FBQL(Acumatica)?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Creating a simple two number calculator using a dictionary',
#   'views': '21 views',
#   'vote_count': '-1'},
#  {'question': 'ClaimsPrincipal Azure Bot Framework',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Regex: Getting standalone numbers and not numeric-related codes',
#   'views': '16 views',
#   'vote_count': '1'},
#  {'question': 'Is there any way to use require and import in node',
#   'views': '27 views',
#   'vote_count': '1'},
#  {'question': 'Garbage Collection for TCP Server using async operations',
#   'views': '16 views',
#   'vote_count': '-1'},
#  {'question': 'Why my rewrite rule in htaccess is working in some case only?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Comparing two characters in C++ [closed]',
#   'views': '33 views',
#   'vote_count': '-3'},
#  {'question': 'Win32DiskImager fails to launch',
#   'views': '10 views',
#   'vote_count': '1'},
#  {'question': 'Is there a preferred method of saving and loading h2o word2vec models in python?',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Short-form to get string length in assembly',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': 'Equalizing switching modes [closed]',
#   'views': '11 views',
#   'vote_count': '-1'},
#  {'question': 'How to use OpenCL optimization with OpenCV4.1 and cmake',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'Argo CD and Kustomize', 'views': '4 views', 'vote_count': '0'},
#  {'question': 'Vectorizing pairwise permutation',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'How do I connect to my MongoDB server with a SSH identity file?',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Having trouble trying to make resizable columns in React',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'pyspark sql server select query issue “An error occurred while calling o39.jdbc”',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'parallel run through testng maven surefire plugin only appends the last result in testng-results.xml',
#   'views': '2 views',
#   'vote_count': '0'},
#  {'question': 'While loop in Jmeter', 'views': '5 views', 'vote_count': '0'},
#  {'question': 'docker nginx proxy to linked container not working',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'FORTRAN OMP parallel do loop scales differently for gfortran and Intel',
#   'views': '5 views',
#   'vote_count': '1'},
#  {'question': 'Rails 4 AR .select includes pk field in result even if result is grouped (as opposed to Rails 3.2)',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Python Local Package Creation/Import Failing (Miserably)',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': "Best way to export data from other company's SAP",
#   'views': '11 views',
#   'vote_count': '-1'},
#  {'question': 'React Simple WebRTC Choose Devices',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'PHP Batch upload array data',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': "Why am I getting this error message in c++ (error: cannot convert 'std::__cxxll::string' )",
#   'views': '28 views',
#   'vote_count': '0'},
#  {'question': 'Limit stdout and stderror log file size',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Using AVFoundation and AVAudioNode how do I take one audio source and route it to multiple destinations?',
#   'views': '10 views',
#   'vote_count': '2'},
#  {'question': 'Get Element and append multiple times Javascript',
#   'views': '19 views',
#   'vote_count': '1'},
#  {'question': 'How to fix bug with two-way controll swiper in reactjs',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'determinant of a complex matrix in PyTorch',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Socket Daemon Thread Does Not Stop',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'Ignoring duplicate NULL field when inserting data',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Popupwindow ignore any outside window touches but allow window to be touchable',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'How can i call Screen inside App.js with navigationOptions with onPress?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'How to filter contents of SNS message in lambda while posting to slack',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': 'How to break the deadlock between a parent and child thread [closed]',
#   'views': '15 views',
#   'vote_count': '-1'},
#  {'question': 'Why does this loop cause a Key error if the second embedded “if” statement is commented out?',
#   'views': '24 views',
#   'vote_count': '0'},
#  {'question': 'What is the best way to break out of a while loop with a permanent True condition? [closed]',
#   'views': '19 views',
#   'vote_count': '-4'},
#  {'question': 'How to create a 33% / 33% / 33% / 100% / 100% flexbox layout?',
#   'views': '40 views',
#   'vote_count': '1'},
#  {'question': 'Overflow in neural network | Python',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Use token tokens in ANTLR4',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'Compiling generated protobuf files into a static library',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'Dodge theme from certain NodeJS modules in ReactJS',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'How can I add a new preference to my eclipse plugin?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Is there a way to manipulate global dataframe from a method inside a class?',
#   'views': '18 views',
#   'vote_count': '0'},
#  {'question': 'Remove TOC in RTF doxygen output',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'net::ERR_RESPONSE_HEADERS_MULTIPLE_CONTENT_DISPOSITION [closed]',
#   'views': '8 views',
#   'vote_count': '-2'},
#  {'question': 'WebTestClient with get() and requestBody not available',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'How to input file name (without path) in command prompt in Java?',
#   'views': '23 views',
#   'vote_count': '0'},
#  {'question': 'SmtpClient in c# resource is inaccessible due to its protection level',
#   'views': '19 views',
#   'vote_count': '0'},
#  {'question': 'Why do I get C2766: explicit specialization has already been defined when trying to converting from MFC to BCGControlBar',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': 'ElectronNet build is missing needed files',
#   'views': '4 views',
#   'vote_count': '1'},
#  {'question': 'How to start a Kafka-Streams Pipeline by Topology using Quarkus',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Automatic Rollbacks SQLALCHEMY',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How can I update my bash profile to include an alias?',
#   'views': '24 views',
#   'vote_count': '1'},
#  {'question': 'Getting null pointer exception when compariing object with null',
#   'views': '29 views',
#   'vote_count': '0'},
#  {'question': 'Bool=! In unity [duplicate]',
#   'views': '21 views',
#   'vote_count': '-2'},
#  {'question': 'Could not find a generator for route RouteSettings when using bottom nav bar',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'What are ways to solve the logging haystack problem in larger systems?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'Undefined symbol despite libraries being linked',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Concat a Subnet ID reference for azure bastion deployment',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'R long to wide data frame with only 2 columns [duplicate]',
#   'views': '23 views',
#   'vote_count': '1'},
#  {'question': 'iOS14 introducing errors with @State bindings',
#   'views': '22 views',
#   'vote_count': '1'},
#  {'question': 'Problems with routes deploying python flask app in VPS',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'In C++, what is the best way to allocate (and de-allocate) a very large array on a computer cluster?',
#   'views': '42 views',
#   'vote_count': '0'},
#  {'question': 'How to write a scirpt of a given functions with their different parameter like (The Weibull function) without using packages?',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Server in Docker container connection refused, should I add time.Sleep(100 * time.Millisecond) to my tests?',
#   'views': '18 views',
#   'vote_count': '0'},
#  {'question': 'loop through request body node js + express',
#   'views': '33 views',
#   'vote_count': '0'},
#  {'question': 'Is it possible to install Java SDK in Termux?',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'What do the various tables in Hive Metastore contain?',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'React Native FlatList onEndReachedThreshold not detecting position',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'MySQL How can I UPDATE only a subset of huge table (907000 rows)',
#   'views': '33 views',
#   'vote_count': '0'},
#  {'question': 'How does this dayOfTheYear function work?',
#   'views': '19 views',
#   'vote_count': '-1'},
#  {'question': 'In VSCode, how can I turn a multi-line comment into a paragraph with no line breaks?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'how to resolve tomcat 8.5 localhost error?',
#   'views': '14 views',
#   'vote_count': '0'},
#  {'question': 'How to put condition in Regex with multiple patterns?',
#   'views': '29 views',
#   'vote_count': '0'},
#  {'question': 'Observe object change in other ViewController in RxSwift',
#   'views': '7 views',
#   'vote_count': '1'},
#  {'question': 'Cannot install an app after editing the AndroidManifest.xml to enable debugging',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Código para mostrar os números pares entre os número digitados em Java [closed]',
#   'views': '17 views',
#   'vote_count': '-1'},
#  {'question': 'Unable to access application on pod on minikube',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'generate shared access signature through python',
#   'views': '18 views',
#   'vote_count': '0'},
#  {'question': 'Migrating from a Wix bundle to Squirrel for Windows',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Emmet order of generated elements',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Arangodb- does a data dictionary Exist',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'CS50 Speller memory leak',
#   'views': '21 views',
#   'vote_count': '0'},
#  {'question': 'Google cloud SDK shell not displaying correct transcription text',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Sometimes the service worker is getting installed automatically (Webpack + Workbox)',
#   'views': '4 views',
#   'vote_count': '0'},
#  {'question': 'Do Azure VM Extensions persist in an image after sysprepping? [closed]',
#   'views': '7 views',
#   'vote_count': '-1'},
#  {'question': 'How can i Change Widget State if i am on another Page',
#   'views': '18 views',
#   'vote_count': '0'},
#  {'question': 'How to automatically trigger releases in Azure Devops, from multiple branches, using multiple artifacts',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Sublime REPL error anyone have any ideas?',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': 'Processing a huge text file in laravel',
#   'views': '17 views',
#   'vote_count': '0'},
#  {'question': 'Speech recognition crashing',
#   'views': '18 views',
#   'vote_count': '0'},
#  {'question': 'Manually determining whether a number is prime or not, function returns Prime for all odd numbers',
#   'views': '24 views',
#   'vote_count': '-1'},
#  {'question': 'DCMTK dimse status', 'views': '11 views', 'vote_count': '0'},
#  {'question': 'DynamoDB data format to plan JSON using spark',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Google drive API: get the shareable publicly link of a video uploaded',
#   'views': '16 views',
#   'vote_count': '0'},
#  {'question': 'Azure function app cannot connect to queue after upgrade from .net core 2.1 to 3.0',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How to secure ASP.NET Core Web API endpoints to only allow requests from React application?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'Pydbus more notifications same time handling',
#   'views': '7 views',
#   'vote_count': '0'},
#  {'question': 'Using Multiple Switch gives Blanc Compponent in reactjs',
#   'views': '8 views',
#   'vote_count': '0'},
#  {'question': 'Extract the body of all emails in an Outlook folder',
#   'views': '15 views',
#   'vote_count': '0'},
#  {'question': 'How to filter contours based on their approximate shape in a Binary video frames',
#   'views': '11 views',
#   'vote_count': '0'},
#  {'question': '403/HTTP/1.1 403 Forbidden error when uploading the file first time and when i retry for the second time it works',
#   'views': '5 views',
#   'vote_count': '0'},
#  {'question': 'GtkTextView text coloring not working as expected',
#   'views': '6 views',
#   'vote_count': '0'},
#  {'question': 'Creating gif with matplotlib plots in for loop',
#   'views': '9 views',
#   'vote_count': '0'},
#  {'question': 'How to create combinations of elements according to some pattern (order)? [closed]',
#   'views': '33 views',
#   'vote_count': '0'},
#  {'question': 'I need help for Python pyinstaller standalone executable [closed]',
#   'views': '12 views',
#   'vote_count': '-3'},
#  {'question': 'Best practice running queries in Node.js with MongoDB driver 3.6?',
#   'views': '12 views',
#   'vote_count': '0'},
#  {'question': 'In new product type magento 2.4 configurations table does not appear',
#   'views': '3 views',
#   'vote_count': '0'},
#  {'question': 'How do I fix this Encryption and Decryption Program',
#   'views': '20 views',
#   'vote_count': '-1'},
#  {'question': 'How to print a 2D array?',
#   'views': '34 views',
#   'vote_count': '0'},
#  {'question': "Why aren't my error messages showing up when using Django/Python?",
#   'views': '31 views',
#   'vote_count': '0'},
#  {'question': 'Compillar un JOB NO RUNNABLE - DATASTAGE IBM [closed]',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How do you graph a subtraction between two unit functions that have been shifted? [closed]',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'How do you disable validation in jquery on a Stripe payment form',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': 'Terraform: Specify specific Docker Network Name for Output',
#   'views': '10 views',
#   'vote_count': '0'},
#  {'question': "Why isn't “align-items” centering items along the cross axis? [duplicate]",
#   'views': '27 views',
#   'vote_count': '0'},
#  {'question': 'F# function summation [closed]',
#   'views': '9 views',
#   'vote_count': '-1'},
#  ...]
